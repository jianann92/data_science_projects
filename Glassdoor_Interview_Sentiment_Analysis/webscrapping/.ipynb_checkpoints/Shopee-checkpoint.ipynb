# %%
# Importing libraries

import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from matplotlib.pyplot import get_cmap

import plotly.express as px
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup
import regex as re
import requests
from lxml import html
import getpass
from googletrans import Translator
import unicodedata
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jiana\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jiana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import random

opts = Options()
opts.add_argument('user-agent=polar-bear 3.0')
opts.add_argument("--headless")

# %%
# driver = webdriver.Chrome(executable_path = 'C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe', chrome_options = opts)

email = getpass.getpass('Email : ')
password = getpass.getpass('Password : ')

try: 
    driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts) 
    driver.get('https://www.glassdoor.sg/index.htm') 
    driver.implicitly_wait(15)
    
    loginpage = driver.find_element_by_xpath('//*[@id="TopNav"]/nav/div/div/div[4]/div[1]/a')
    loginpage.click()

    loginBox = driver.find_element_by_xpath('//*[@id="userEmail"]') 
    loginBox.send_keys(email)
    
    passWordBox = driver.find_element_by_xpath('//*[@id="userPassword"]')
    passWordBox.send_keys(password)
    
    signin = driver.find_element_by_xpath('//*[@id="LoginModal"]/div/div/div[2]/div[2]/div[2]/div/div/div/div[3]/form/div[3]/div[1]/button')
    signin.click()
    
    print('Login Successful!')

except:
    print('Login Failed')
# Out:
# Email : ········
# Password : ········
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [C:\Users\jiana\.wdm\drivers\chromedriver\win32\86.0.4240.22\chromedriver.exe] found in cache
# <ipython-input-3-42d1c69f0a0f>:7: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts)
# Login Successful!

# %%
url = 'https://www.glassdoor.sg/Interview/TikTok-Interview-Questions-E2230881.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [7,11]
max_page = 26            # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    tiktok_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for Tiktok interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# Refreshing page 1...
# 1 of 25
# 2 of 25
# 3 of 25
# 4 of 25
# 5 of 25
# 6 of 25
# Pause to rest. Run time : 0.83 minutes
#
# Scraping page :
# 7 of 25
# 8 of 25
# 9 of 25
# 10 of 25
# Pause to rest. Run time : 1.3 minutes
#
# Scraping page :
# 11 of 25
# 12 of 25
# 13 of 25
# Pause to rest. Run time : 1.61 minutes
#
# Scraping page :
# 14 of 25
# 15 of 25
# 16 of 25
# 17 of 25
# 18 of 25
# 19 of 25
# 20 of 25
# 21 of 25
# Pause to rest. Run time : 2.58 minutes
#
# Scraping page :
# 22 of 25
# 23 of 25
# 24 of 25
# 25 of 25
#
# Successfully scraped for Tiktok interviews.
# Total duration : 3.14 minutes

# %%
url = 'https://www.glassdoor.sg/Interview/ByteDance-Interview-Questions-E1624196.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [7,11]
max_page = 23            # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    bytedance_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for ByteDance_df interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 22
# 2 of 22
# 3 of 22
# 4 of 22
# 5 of 22
# 6 of 22
# Pause to rest. Run time : 0.49 minutes
#
# Scraping page :
# 7 of 22
# 8 of 22
# 9 of 22
# 10 of 22
# Pause to rest. Run time : 0.92 minutes
#
# Scraping page :
# 11 of 22
# 12 of 22
# 13 of 22
# Pause to rest. Run time : 1.23 minutes
#
# Scraping page :
# 14 of 22
# 15 of 22
# 16 of 22
# 17 of 22
# 18 of 22
# 19 of 22
# 20 of 22
# 21 of 22
# Pause to rest. Run time : 2.06 minutes
#
# Scraping page :
# 22 of 22
#
# Successfully scraped for ByteDance_df interviews.
# Total duration : 2.27 minutes

# %%
tiktok_df['source'] = 'Tiktok'
bytedance_df['source'] = 'ByteDance'

# %%
df = pd.concat([tiktok_df,bytedance_df])

# %%
df
# Out:
#                                               question           offer  \
# 0                     Tell me about your experience           No Offer
# 1     What do you enjoy the most about working with...  Declined Offer
# 2        What are some projects you have worked on?           No Offer
# 3     describe the color green to a homeless person           No Offer
# 4                  two sum. and reverse linked list           No Offer
# ..                                                 ...             ...
# 215   Questions related to influencer marketing, ot...  Accepted Offer
# 216   what kind of techniques did you use in the pa...  Accepted Offer
# 217   Basic JavaScript questions, some simple algor...  Accepted Offer
# 218   What is your experience for working under the...  Accepted Offer
# 219                           reverse a binary tree     Accepted Offer
#
#               experience           difficulty  \
# 0    Negative Experience       Easy Interview
# 1    Positive Experience    Average Interview
# 2    Negative Experience    Average Interview
# 3    Negative Experience  Difficult Interview
# 4    Negative Experience    Average Interview
# ..                   ...                  ...
# 215  Negative Experience    Average Interview
# 216   Neutral Experience       Easy Interview
# 217  Positive Experience    Average Interview
# 218  Positive Experience       Easy Interview
# 219  Positive Experience  Difficult Interview
#
#                                              interview     source
# 0                                                  NaN     Tiktok
# 1    Recruiter sent an InMail to me on LinkedIn out...     Tiktok
# 2                                                  NaN     Tiktok
# 3                                                  NaN     Tiktok
# 4    begins by self introduction. The team organiza...     Tiktok
# ..                                                 ...        ...
# 215  Happened over video call since the team was ba...  ByteDance
# 216  several rounds of interviews from department l...  ByteDance
# 217  I only participated in the intern interview, s...  ByteDance
# 218  The interview consisted on 3 steps - 1 phone s...  ByteDance
# 219  a data engineer called me and asked a bunch of...  ByteDance
#
# [470 rows x 6 columns]

# %%
df['interview'].fillna('', inplace = True)
df['question'].fillna('', inplace = True)
# fill all nan with ''

# %%
df[df['experience'] == 'Neutral Experience']
# Out:
#                                               question           offer  \
# 18                                                            No Offer
# 19    Tell me about your projects and explain to me...        No Offer
# 29       Leetcode medium (sort of on the easy side)           No Offer
# 36    Describe a time you failed and how you dealt ...        No Offer
# 37    What are two things you are proud to have acc...        No Offer
# ..                                                 ...             ...
# 181                   Introduce yourself,video quiz     Declined Offer
# 202   From your opinion, what are inappropriate con...        No Offer
# 208       technical questions and self introduction     Declined Offer
# 210   Tell me about your current job? How do you th...  Accepted Offer
# 216   what kind of techniques did you use in the pa...  Accepted Offer
#
#              experience           difficulty  \
# 18   Neutral Experience  Difficult Interview
# 19   Neutral Experience    Average Interview
# 29   Neutral Experience    Average Interview
# 36   Neutral Experience       Easy Interview
# 37   Neutral Experience    Average Interview
# ..                  ...                  ...
# 181  Neutral Experience       Easy Interview
# 202  Neutral Experience       Easy Interview
# 208  Neutral Experience       Easy Interview
# 210  Neutral Experience    Average Interview
# 216  Neutral Experience       Easy Interview
#
#                                              interview     source
# 18   I interviewed with TikTok in August 2020. I ap...     Tiktok
# 19                                                         Tiktok
# 29   Basic introduction, past work experiences, cha...     Tiktok
# 36                                                         Tiktok
# 37                                                         Tiktok
# ..                                                 ...        ...
# 181  HR got in touch with me and was arranged 3 rou...  ByteDance
# 202  I had total three video-call interview with th...  ByteDance
# 208  quite fast and smooth, but what they offer is ...  ByteDance
# 210  phone call first with one of their team member...  ByteDance
# 216  several rounds of interviews from department l...  ByteDance
#
# [70 rows x 6 columns]

# %%
df['experience'] = df['experience'].apply(lambda exp : 1 if exp == 'Positive Experience' else 0)

# %%
df['length'] = df['interview'].apply(len)
df = df[df['length']!=0]

# %%
df.interview.isna().sum()
# Out:
# 0

# %%
df.reset_index(inplace = True)
df.drop(columns = 'index', inplace = True)
df.rename(columns = {'experience' : 'target_variable'}, inplace = True)
# Out:
# C:\Users\jiana\Anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\jiana\Anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df.target_variable.value_counts()
# Out:
# 0    133
# 1    105
# Name: target_variable, dtype: int64

# %%
# processing text, without lemmatizing or stemming
p_stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()
# stop_set = ['the', 'a', 'an', 'i', 'he', 'she', 'they', 'to', 'of', 'it', 'from']
stop_words = set(stopwords.words('english'))
stop_words |= set(['interview','interviewer','question','recruiter','process','ask','amazon','phone','questions',
                   'apple','facebook','google','microsoft','round', 'one'])
stop_words.remove('not')

# Adding CSS class icon into list of words to remove
swear_words_corpus = requests.get("http://www.cs.cmu.edu/~biglou/resources/bad-words.txt").text # Swear words to be removed
swear_words = re.sub('[\n]', ' ', swear_words_corpus)
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)


corpus = []
# def processing_text(texts): # Function to process texts
for i in range(0,len(df)):
    
    word = emoji_pattern.sub(r'', df['interview'][i]) # no emoji
    word = BeautifulSoup(word,'lxml').getText()
    word = re.sub('[^a-zA-Z]',' ',word.lower())    # Remove non-letters and convert all to lower case
    word = word.split() # Split into individual words
    
    clean = [w for w in word if w not in swear_words]
    clean = [w for w in word if w not in stop_words] # Removing stopwords and stemming remaining words
#     clean = [lemmatizer.lemmatize(w) for w in word if w not in stop_words] # Removing stopwords and lemmatizing remaining
    clean = ' '.join(clean)
    corpus.append(clean)

# %%
cleaned_corpus = []

for i in corpus:
    word = i.split() # Split into individual words
#     clean = [p_stemmer.stem(w) for w in word] # Removing stopwords and stemming remaining words
    clean = [lemmatizer.lemmatize(w) for w in word] # Removing stopwords and lemmatizing remaining
    clean = [w for w in clean if w not in stop_words]
    clean = [w for w in clean if len(w) >= 2] # Remove all words that has single alphabets
    clean = ' '.join(clean)
    cleaned_corpus.append(clean)

# %%
df['text'] = cleaned_corpus
# Out:
# <ipython-input-18-f5a9ee18bd61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = cleaned_corpus

# %%
df
# Out:
#                                               question           offer  \
# 0     What do you enjoy the most about working with...  Declined Offer
# 1                  two sum. and reverse linked list           No Offer
# 2                                                       Declined Offer
# 3                     So.... Tell me about yourself           No Offer
# 4                 Why are you interested in TikTok?           No Offer
# ..                                                 ...             ...
# 233   Questions related to influencer marketing, ot...  Accepted Offer
# 234   what kind of techniques did you use in the pa...  Accepted Offer
# 235   Basic JavaScript questions, some simple algor...  Accepted Offer
# 236   What is your experience for working under the...  Accepted Offer
# 237                           reverse a binary tree     Accepted Offer
#
#      target_variable           difficulty  \
# 0                  1    Average Interview
# 1                  0    Average Interview
# 2                  1       Easy Interview
# 3                  0    Average Interview
# 4                  1       Easy Interview
# ..               ...                  ...
# 233                0    Average Interview
# 234                0       Easy Interview
# 235                1    Average Interview
# 236                1       Easy Interview
# 237                1  Difficult Interview
#
#                                              interview     source  length  \
# 0    Recruiter sent an InMail to me on LinkedIn out...     Tiktok     348
# 1    begins by self introduction. The team organiza...     Tiktok     359
# 2    It wasn't well organized. The HR specialist on...     Tiktok     224
# 3    The mess that the interview was makes me wonde...     Tiktok     225
# 4    The interview was very professional and straig...     Tiktok     186
# ..                                                 ...        ...     ...
# 233  Happened over video call since the team was ba...  ByteDance     300
# 234  several rounds of interviews from department l...  ByteDance     255
# 235  I only participated in the intern interview, s...  ByteDance     181
# 236  The interview consisted on 3 steps - 1 phone s...  ByteDance     321
# 237  a data engineer called me and asked a bunch of...  ByteDance     260
#
#                                                   text
# 0    sent inmail linkedin outlining past experience...
# 1    begin self introduction team organization proj...
# 2    well organized hr specialist communicated timi...
# 3    mess make wonder much really stuff together cu...
# 4    professional straightforward asked basic help ...
# ..                                                 ...
# 233  happened video call since team based china rol...
# 234  several department lead hr lead quite detailed...
# 235  participated intern much easier fall recruitme...
# 236  consisted step screening mainly focused shift ...
# 237  data engineer called asked bunch behavioral ba...
#
# [238 rows x 8 columns]

# %%
df.to_csv('../datasets/production.csv', index = False)
