# %%
# Importing libraries

import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from matplotlib.pyplot import get_cmap

#import plotly.express as px
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup
import regex as re
import requests
from lxml import html
import getpass
from googletrans import Translator
import unicodedata
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jiana\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jiana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import random

opts = Options()
opts.add_argument('user-agent=polar-bear 3.0')
opts.add_argument("--headless")

# %%
# driver = webdriver.Chrome(executable_path = 'C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe', chrome_options = opts)

email = getpass.getpass('Email : ')
password = getpass.getpass('Password : ')

try: 
    driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts) 
    driver.get('https://www.glassdoor.sg/index.htm') 
    driver.implicitly_wait(15)
    
    loginpage = driver.find_element_by_xpath('//*[@id="TopNav"]/nav/div/div/div[4]/div[1]/a')
    loginpage.click()

    loginBox = driver.find_element_by_xpath('//*[@id="userEmail"]') 
    loginBox.send_keys(email)
    
    passWordBox = driver.find_element_by_xpath('//*[@id="userPassword"]')
    passWordBox.send_keys(password)
    
    signin = driver.find_element_by_xpath('//*[@id="LoginModal"]/div/div/div[2]/div[2]/div[2]/div/div/div/div[3]/form/div[3]/div[1]/button')
    signin.click()
    
    print('Login Successful!')

except:
    print('Login Failed')
# Out:
# Email : ········
# Password : ········
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [C:\Users\jiana\.wdm\drivers\chromedriver\win32\86.0.4240.22\chromedriver.exe] found in cache
# <ipython-input-3-42d1c69f0a0f>:7: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts)
# Login Successful!

# %%
url = 'https://www.glassdoor.sg/Interview/Walmart-Interview-Questions-E715.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,71]
max_page = 970            # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    walmart_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for walmart interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 969
# 2 of 969
# 3 of 969
# 4 of 969
# 5 of 969
# 6 of 969
# 7 of 969
# 8 of 969
# 9 of 969
# 10 of 969
# 11 of 969
# 12 of 969
# 13 of 969
# 14 of 969
# 15 of 969
# 16 of 969
# 17 of 969
# 18 of 969
# 19 of 969
# 20 of 969
# 21 of 969
# 22 of 969
# 23 of 969
# 24 of 969
# 25 of 969
# 26 of 969
# 27 of 969
# 28 of 969
# 29 of 969
# 30 of 969
# 31 of 969
# 32 of 969
# 33 of 969
# 34 of 969
# Refreshing page 35...
# Refreshing page 35...
# 35 of 969
# 36 of 969
# Pause to rest. Run time : 10.82 minutes
#
# Scraping page :
# 37 of 969
# 38 of 969
# 39 of 969
# 40 of 969
# 41 of 969
# 42 of 969
# 43 of 969
# 44 of 969
# 45 of 969
# 46 of 969
# 47 of 969
# 48 of 969
# 49 of 969
# 50 of 969, Run time : 12.78 minutes
# 51 of 969
# 52 of 969
# 53 of 969
# 54 of 969
# 55 of 969
# 56 of 969
# 57 of 969
# 58 of 969
# 59 of 969
# 60 of 969
# 61 of 969
# 62 of 969
# 63 of 969
# 64 of 969
# 65 of 969
# 66 of 969
# 67 of 969
# 68 of 969
# 69 of 969
# 70 of 969
# Pause to rest. Run time : 15.62 minutes
#
# Scraping page :
# 71 of 969
# 72 of 969
# 73 of 969
# Pause to rest. Run time : 16.07 minutes
#
# Scraping page :
# 74 of 969
# 75 of 969
# 76 of 969
# 77 of 969
# 78 of 969
# 79 of 969
# 80 of 969
# 81 of 969
# 82 of 969
# 83 of 969
# 84 of 969
# 85 of 969
# 86 of 969
# 87 of 969
# 88 of 969
# 89 of 969
# 90 of 969
# 91 of 969
# 92 of 969
# 93 of 969
# 94 of 969
# 95 of 969
# 96 of 969
# 97 of 969
# 98 of 969
# 99 of 969
# 100 of 969, Run time : 19.76 minutes
# 101 of 969
# 102 of 969
# 103 of 969
# 104 of 969
# 105 of 969
# 106 of 969
# 107 of 969
# 108 of 969
# 109 of 969
# 110 of 969
# 111 of 969
# 112 of 969
# 113 of 969
# 114 of 969
# 115 of 969
# 116 of 969
# 117 of 969
# 118 of 969
# 119 of 969
# 120 of 969
# 121 of 969
# 122 of 969
# 123 of 969
# 124 of 969
# 125 of 969
# 126 of 969
# 127 of 969
# 128 of 969
# 129 of 969
# 130 of 969
# 131 of 969
# 132 of 969
# 133 of 969
# 134 of 969
# 135 of 969
# 136 of 969
# 137 of 969
# 138 of 969
# 139 of 969
# 140 of 969
# 141 of 969
# Pause to rest. Run time : 25.43 minutes
#
# Scraping page :
# 142 of 969
# 143 of 969
# 144 of 969
# 145 of 969
# 146 of 969
# 147 of 969
# Pause to rest. Run time : 26.4 minutes
#
# Scraping page :
# 148 of 969
# 149 of 969
# 150 of 969, Run time : 26.96 minutes
# 151 of 969
# 152 of 969
# 153 of 969
# 154 of 969
# 155 of 969
# 156 of 969
# 157 of 969
# 158 of 969
# 159 of 969
# 160 of 969
# 161 of 969
# 162 of 969
# 163 of 969
# 164 of 969
# 165 of 969
# 166 of 969
# 167 of 969
# 168 of 969
# 169 of 969
# 170 of 969
# 171 of 969
# 172 of 969
# 173 of 969
# 174 of 969
# 175 of 969
# 176 of 969
# 177 of 969
# 178 of 969
# 179 of 969
# 180 of 969
# 181 of 969
# 182 of 969
# 183 of 969
# 184 of 969
# 185 of 969
# 186 of 969
# 187 of 969
# 188 of 969
# 189 of 969
# 190 of 969
# 191 of 969
# 192 of 969
# 193 of 969
# 194 of 969
# 195 of 969
# 196 of 969
# 197 of 969
# 198 of 969
# 199 of 969
# 200 of 969, Run time : 34.88 minutes
# 201 of 969
# 202 of 969
# 203 of 969
# 204 of 969
# 205 of 969
# 206 of 969
# 207 of 969
# 208 of 969
# 209 of 969
# 210 of 969
# 211 of 969
# 212 of 969
# Pause to rest. Run time : 36.8 minutes
#
# Scraping page :
# 213 of 969
# 214 of 969
# 215 of 969
# 216 of 969
# 217 of 969
# 218 of 969
# 219 of 969
# 220 of 969
# 221 of 969
# Pause to rest. Run time : 38.04 minutes
#
# Scraping page :
# 222 of 969
# 223 of 969
# 224 of 969
# 225 of 969
# 226 of 969
# 227 of 969
# 228 of 969
# 229 of 969
# 230 of 969
# 231 of 969
# 232 of 969
# 233 of 969
# 234 of 969
# 235 of 969
# 236 of 969
# 237 of 969
# 238 of 969
# 239 of 969
# 240 of 969
# 241 of 969
# 242 of 969
# 243 of 969
# 244 of 969
# 245 of 969
# 246 of 969
# 247 of 969
# 248 of 969
# 249 of 969
# 250 of 969, Run time : 42.69 minutes
# 251 of 969
# 252 of 969
# 253 of 969
# 254 of 969
# 255 of 969
# 256 of 969
# 257 of 969
# 258 of 969
# 259 of 969
# 260 of 969
# 261 of 969
# 262 of 969
# 263 of 969
# 264 of 969
# 265 of 969
# 266 of 969
# 267 of 969
# 268 of 969
# 269 of 969
# 270 of 969
# 271 of 969
# 272 of 969
# 273 of 969
# 274 of 969
# 275 of 969
# 276 of 969
# Refreshing page 277...
# 277 of 969
# 278 of 969
# 279 of 969
# 280 of 969
# 281 of 969
# 282 of 969
# 283 of 969
# Pause to rest. Run time : 47.67 minutes
#
# Scraping page :
# 284 of 969
# 285 of 969
# 286 of 969
# 287 of 969
# 288 of 969
# 289 of 969
# 290 of 969
# 291 of 969
# 292 of 969
# 293 of 969
# 294 of 969
# 295 of 969
# Pause to rest. Run time : 49.3 minutes
#
# Scraping page :
# 296 of 969
# 297 of 969
# 298 of 969
# 299 of 969
# 300 of 969, Run time : 50.03 minutes
# 301 of 969
# 302 of 969
# 303 of 969
# 304 of 969
# 305 of 969
# 306 of 969
# 307 of 969
# 308 of 969
# 309 of 969
# 310 of 969
# 311 of 969
# 312 of 969
# 313 of 969
# 314 of 969
# 315 of 969
# 316 of 969
# 317 of 969
# 318 of 969
# 319 of 969
# 320 of 969
# 321 of 969
# 322 of 969
# 323 of 969
# 324 of 969
# 325 of 969
# 326 of 969
# 327 of 969
# 328 of 969
# 329 of 969
# 330 of 969
# 331 of 969
# 332 of 969
# 333 of 969
# 334 of 969
# 335 of 969
# 336 of 969
# 337 of 969
# 338 of 969
# 339 of 969
# 340 of 969
# 341 of 969
# 342 of 969
# 343 of 969
# 344 of 969
# 345 of 969
# 346 of 969
# 347 of 969
# 348 of 969
# 349 of 969
# 350 of 969, Run time : 57.07 minutes
# 351 of 969
# 352 of 969
# 353 of 969
# 354 of 969
# Pause to rest. Run time : 57.71 minutes
#
# Scraping page :
# 355 of 969
# 356 of 969
# 357 of 969
# 358 of 969
# 359 of 969
# 360 of 969
# 361 of 969
# 362 of 969
# 363 of 969
# 364 of 969
# 365 of 969
# 366 of 969
# 367 of 969
# 368 of 969
# 369 of 969
# Pause to rest. Run time : 59.92 minutes
#
# Scraping page :
# 370 of 969
# 371 of 969
# 372 of 969
# 373 of 969
# 374 of 969
# 375 of 969
# 376 of 969
# 377 of 969
# 378 of 969
# 379 of 969
# 380 of 969
# 381 of 969
# 382 of 969
# 383 of 969
# 384 of 969
# 385 of 969
# 386 of 969
# 387 of 969
# 388 of 969
# 389 of 969
# 390 of 969
# 391 of 969
# 392 of 969
# 393 of 969
# 394 of 969
# 395 of 969
# 396 of 969
# 397 of 969
# 398 of 969
# 399 of 969
# 400 of 969, Run time : 64.4 minutes
# 401 of 969
# 402 of 969
# 403 of 969
# 404 of 969
# 405 of 969
# 406 of 969
# 407 of 969
# 408 of 969
# 409 of 969
# 410 of 969
# 411 of 969
# 412 of 969
# 413 of 969
# 414 of 969
# 415 of 969
# 416 of 969
# 417 of 969
# 418 of 969
# 419 of 969
# 420 of 969
# 421 of 969
# 422 of 969
# 423 of 969
# 424 of 969
# 425 of 969
# Pause to rest. Run time : 68.07 minutes
#
# Scraping page :
# 426 of 969
# 427 of 969
# 428 of 969
# 429 of 969
# 430 of 969
# 431 of 969
# 432 of 969
# 433 of 969
# 434 of 969
# 435 of 969
# 436 of 969
# 437 of 969
# 438 of 969
# 439 of 969
# 440 of 969
# 441 of 969
# 442 of 969
# 443 of 969
# Pause to rest. Run time : 70.57 minutes
#
# Scraping page :
# 444 of 969
# 445 of 969
# 446 of 969
# 447 of 969
# 448 of 969
# 449 of 969
# 450 of 969, Run time : 71.71 minutes
# 451 of 969
# 452 of 969
# 453 of 969
# 454 of 969
# 455 of 969
# 456 of 969
# 457 of 969
# 458 of 969
# 459 of 969
# 460 of 969
# 461 of 969
# 462 of 969
# 463 of 969
# 464 of 969
# 465 of 969
# 466 of 969
# 467 of 969
# 468 of 969
# 469 of 969
# 470 of 969
# 471 of 969
# 472 of 969
# 473 of 969
# 474 of 969
# 475 of 969
# 476 of 969
# 477 of 969
# 478 of 969
# 479 of 969
# 480 of 969
# 481 of 969
# 482 of 969
# 483 of 969
# 484 of 969
# 485 of 969
# 486 of 969
# 487 of 969
# 488 of 969
# 489 of 969
# 490 of 969
# 491 of 969
# 492 of 969
# 493 of 969
# 494 of 969
# 495 of 969
# 496 of 969
# Pause to rest. Run time : 78.12 minutes
#
# Scraping page :
# 497 of 969
# 498 of 969
# 499 of 969
# 500 of 969, Run time : 78.65 minutes
# 501 of 969
# 502 of 969
# 503 of 969
# 504 of 969
# 505 of 969
# 506 of 969
# 507 of 969
# 508 of 969
# 509 of 969
# 510 of 969
# 511 of 969
# 512 of 969
# 513 of 969
# 514 of 969
# 515 of 969
# 516 of 969
# 517 of 969
# Pause to rest. Run time : 80.96 minutes
#
# Scraping page :
# 518 of 969
# 519 of 969
# 520 of 969
# 521 of 969
# 522 of 969
# 523 of 969
# 524 of 969
# 525 of 969
# 526 of 969
# 527 of 969
# 528 of 969
# 529 of 969
# 530 of 969
# 531 of 969
# 532 of 969
# 533 of 969
# 534 of 969
# 535 of 969
# 536 of 969
# 537 of 969
# 538 of 969
# 539 of 969
# 540 of 969
# 541 of 969
# 542 of 969
# 543 of 969
# 544 of 969
# 545 of 969
# 546 of 969
# 547 of 969
# 548 of 969
# 549 of 969
# 550 of 969, Run time : 86.14 minutes
# 551 of 969
# 552 of 969
# 553 of 969
# 554 of 969
# 555 of 969
# 556 of 969
# 557 of 969
# 558 of 969
# 559 of 969
# 560 of 969
# 561 of 969
# 562 of 969
# 563 of 969
# 564 of 969
# 565 of 969
# 566 of 969
# 567 of 969
# Pause to rest. Run time : 88.68 minutes
#
# Scraping page :
# 568 of 969
# 569 of 969
# 570 of 969
# 571 of 969
# 572 of 969
# 573 of 969
# 574 of 969
# 575 of 969
# 576 of 969
# 577 of 969
# 578 of 969
# 579 of 969
# 580 of 969
# 581 of 969
# 582 of 969
# 583 of 969
# 584 of 969
# 585 of 969
# 586 of 969
# 587 of 969
# 588 of 969
# 589 of 969
# 590 of 969
# 591 of 969
# Pause to rest. Run time : 92.46 minutes
#
# Scraping page :
# 592 of 969
# 593 of 969
# 594 of 969
# 595 of 969
# 596 of 969
# 597 of 969
# 598 of 969
# 599 of 969
# 600 of 969, Run time : 93.79 minutes
# 601 of 969
# 602 of 969
# 603 of 969
# 604 of 969
# 605 of 969
# 606 of 969
# 607 of 969
# 608 of 969
# 609 of 969
# 610 of 969
# 611 of 969
# 612 of 969
# 613 of 969
# 614 of 969
# 615 of 969
# 616 of 969
# 617 of 969
# 618 of 969
# 619 of 969
# 620 of 969
# 621 of 969
# 622 of 969
# 623 of 969
# 624 of 969
# 625 of 969
# 626 of 969
# 627 of 969
# 628 of 969
# 629 of 969
# 630 of 969
# 631 of 969
# 632 of 969
# 633 of 969
# 634 of 969
# 635 of 969
# 636 of 969
# 637 of 969
# 638 of 969
# Pause to rest. Run time : 100.61 minutes
#
# Scraping page :
# 639 of 969
# 640 of 969
# 641 of 969
# 642 of 969
# 643 of 969
# 644 of 969
# 645 of 969
# 646 of 969
# 647 of 969
# 648 of 969
# 649 of 969
# 650 of 969, Run time : 102.31 minutes
# 651 of 969
# 652 of 969
# 653 of 969
# 654 of 969
# 655 of 969
# 656 of 969
# 657 of 969
# 658 of 969
# 659 of 969
# 660 of 969
# 661 of 969
# 662 of 969
# 663 of 969
# 664 of 969
# 665 of 969
# Pause to rest. Run time : 104.47 minutes
#
# Scraping page :
# 666 of 969
# 667 of 969
# 668 of 969
# 669 of 969
# 670 of 969
# 671 of 969
# 672 of 969
# 673 of 969
# 674 of 969
# 675 of 969
# 676 of 969
# 677 of 969
# 678 of 969
# 679 of 969
# 680 of 969
# 681 of 969
# 682 of 969
# 683 of 969
# 684 of 969
# 685 of 969
# 686 of 969
# 687 of 969
# 688 of 969
# Refreshing page 689...
# 689 of 969
# 690 of 969
# 691 of 969
# 692 of 969
# 693 of 969
# 694 of 969
# 695 of 969
# 696 of 969
# 697 of 969
# 698 of 969
# 699 of 969
# 700 of 969, Run time : 109.67 minutes
# 701 of 969
# 702 of 969
# 703 of 969
# 704 of 969
# 705 of 969
# 706 of 969
# 707 of 969
# 708 of 969
# 709 of 969
# Pause to rest. Run time : 111.03 minutes
#
# Scraping page :
# 710 of 969
# 711 of 969
# 712 of 969
# 713 of 969
# 714 of 969
# 715 of 969
# 716 of 969
# 717 of 969
# 718 of 969
# 719 of 969
# 720 of 969
# 721 of 969
# 722 of 969
# 723 of 969
# 724 of 969
# 725 of 969
# 726 of 969
# 727 of 969
# 728 of 969
# 729 of 969
# 730 of 969
# 731 of 969
# 732 of 969
# 733 of 969
# 734 of 969
# 735 of 969
# 736 of 969
# 737 of 969
# 738 of 969
# 739 of 969
# Pause to rest. Run time : 115.61 minutes
#
# Scraping page :
# 740 of 969
# 741 of 969
# 742 of 969
# 743 of 969
# 744 of 969
# 745 of 969
# 746 of 969
# 747 of 969
# 748 of 969
# 749 of 969
# 750 of 969, Run time : 117.51 minutes
# 751 of 969
# 752 of 969
# 753 of 969
# 754 of 969
# 755 of 969
# 756 of 969
# 757 of 969
# 758 of 969
# 759 of 969
# 760 of 969
# 761 of 969
# 762 of 969
# 763 of 969
# 764 of 969
# 765 of 969
# 766 of 969
# 767 of 969
# 768 of 969
# 769 of 969
# 770 of 969
# 771 of 969
# 772 of 969
# 773 of 969
# 774 of 969
# 775 of 969
# 776 of 969
# 777 of 969
# 778 of 969
# 779 of 969
# 780 of 969
# Pause to rest. Run time : 121.97 minutes
#
# Scraping page :
# 781 of 969
# 782 of 969
# 783 of 969
# 784 of 969
# 785 of 969
# 786 of 969
# 787 of 969
# 788 of 969
# 789 of 969
# 790 of 969
# 791 of 969
# 792 of 969
# 793 of 969
# 794 of 969
# 795 of 969
# 796 of 969
# 797 of 969
# 798 of 969
# 799 of 969
# 800 of 969, Run time : 125.05 minutes
# 801 of 969
# 802 of 969
# 803 of 969
# 804 of 969
# 805 of 969
# 806 of 969
# 807 of 969
# 808 of 969
# 809 of 969
# 810 of 969
# 811 of 969
# 812 of 969
# 813 of 969
# Pause to rest. Run time : 126.79 minutes
#
# Scraping page :
# 814 of 969
# 815 of 969
# 816 of 969
# 817 of 969
# 818 of 969
# 819 of 969
# 820 of 969
# 821 of 969
# 822 of 969
# 823 of 969
# 824 of 969
# 825 of 969
# 826 of 969
# 827 of 969
# 828 of 969
# 829 of 969
# 830 of 969
# 831 of 969
# 832 of 969
# 833 of 969
# 834 of 969
# 835 of 969
# 836 of 969
# 837 of 969
# 838 of 969
# 839 of 969
# 840 of 969
# 841 of 969
# 842 of 969
# 843 of 969
# 844 of 969
# 845 of 969
# 846 of 969
# 847 of 969
# 848 of 969
# 849 of 969
# 850 of 969, Run time : 132.14 minutes
# 851 of 969
# Pause to rest. Run time : 132.32 minutes
#
# Scraping page :
# 852 of 969
# 853 of 969
# 854 of 969
# 855 of 969
# 856 of 969
# 857 of 969
# 858 of 969
# 859 of 969
# 860 of 969
# 861 of 969
# 862 of 969
# 863 of 969
# 864 of 969
# 865 of 969
# 866 of 969
# 867 of 969
# 868 of 969
# 869 of 969
# 870 of 969
# 871 of 969
# 872 of 969
# 873 of 969
# 874 of 969
# 875 of 969
# 876 of 969
# 877 of 969
# 878 of 969
# 879 of 969
# 880 of 969
# 881 of 969
# 882 of 969
# 883 of 969
# 884 of 969
# 885 of 969
# 886 of 969
# 887 of 969
# Pause to rest. Run time : 137.55 minutes
#
# Scraping page :
# 888 of 969
# 889 of 969
# 890 of 969
# 891 of 969
# 892 of 969
# 893 of 969
# 894 of 969
# 895 of 969
# 896 of 969
# 897 of 969
# 898 of 969
# 899 of 969
# 900 of 969, Run time : 139.63 minutes
# 901 of 969
# 902 of 969
# 903 of 969
# 904 of 969
# 905 of 969
# 906 of 969
# 907 of 969
# 908 of 969
# 909 of 969
# 910 of 969
# 911 of 969
# 912 of 969
# 913 of 969
# 914 of 969
# 915 of 969
# 916 of 969
# 917 of 969
# 918 of 969
# 919 of 969
# 920 of 969
# 921 of 969
# 922 of 969
# Pause to rest. Run time : 143.13 minutes
#
# Scraping page :
# 923 of 969
# 924 of 969
# Pause to rest. Run time : 143.42 minutes
#
# Scraping page :
# 925 of 969
# 926 of 969
# 927 of 969
# 928 of 969
# 929 of 969
# 930 of 969
# 931 of 969
# 932 of 969
# 933 of 969
# 934 of 969
# 935 of 969
# 936 of 969
# 937 of 969
# 938 of 969
# 939 of 969
# 940 of 969
# 941 of 969
# 942 of 969
# 943 of 969
# 944 of 969
# 945 of 969
# 946 of 969
# 947 of 969
# 948 of 969
# 949 of 969
# 950 of 969, Run time : 147.4 minutes
# 951 of 969
# 952 of 969
# 953 of 969
# 954 of 969
# 955 of 969
# 956 of 969
# 957 of 969
# 958 of 969
# 959 of 969
# 960 of 969
# 961 of 969
# 962 of 969
# 963 of 969
# 964 of 969
# 965 of 969
# 966 of 969
# 967 of 969
# 968 of 969
# 969 of 969
#
# Successfully scraped for walmart interviews.
# Total duration : 150.21 minutes

# %%
url = 'https://www.glassdoor.sg/Interview/Accenture-Interview-Questions-E4138.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,71]
max_page = 1485            # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    accenture_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for accenture interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 1484
# 2 of 1484
# 3 of 1484
# 4 of 1484
# 5 of 1484
# 6 of 1484
# 7 of 1484
# 8 of 1484
# 9 of 1484
# 10 of 1484
# 11 of 1484
# 12 of 1484
# 13 of 1484
# 14 of 1484
# 15 of 1484
# 16 of 1484
# 17 of 1484
# 18 of 1484
# 19 of 1484
# 20 of 1484
# 21 of 1484
# 22 of 1484
# 23 of 1484
# 24 of 1484
# 25 of 1484
# 26 of 1484
# 27 of 1484
# Refreshing page 28...
# 28 of 1484
# 29 of 1484
# 30 of 1484
# 31 of 1484
# 32 of 1484
# 33 of 1484
# 34 of 1484
# 35 of 1484
# 36 of 1484
# Pause to rest. Run time : 4.25 minutes
#
# Scraping page :
# 37 of 1484
# 38 of 1484
# 39 of 1484
# 40 of 1484
# 41 of 1484
# 42 of 1484
# 43 of 1484
# 44 of 1484
# 45 of 1484
# 46 of 1484
# 47 of 1484
# 48 of 1484
# 49 of 1484
# 50 of 1484, Run time : 5.92 minutes
# 51 of 1484
_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    dyson_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for dyson interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 40
# 2 of 40
# 3 of 40
# 4 of 40
# 5 of 40
# 6 of 40
# 7 of 40
# 8 of 40
# 9 of 40
# 10 of 40
# 11 of 40
# 12 of 40
# 13 of 40
# 14 of 40
# 15 of 40
# 16 of 40
# 17 of 40
# 18 of 40
# 19 of 40
# 20 of 40
# 21 of 40
# 22 of 40
# 23 of 40
# 24 of 40
# 25 of 40
# 26 of 40
# 27 of 40
# 28 of 40
# 29 of 40
# 30 of 40
# 31 of 40
# 32 of 40
# 33 of 40
# 34 of 40
# 35 of 40
# 36 of 40
# Pause to rest. Run time : 3.8 minutes
#
# Scraping page :
# 37 of 40
# 38 of 40
# 39 of 40
# 40 of 40
#
# Successfully scraped for dyson interviews.
# Total duration : 4.32 minutes

# %%
walmart_df['source'] = 'walmart'
accenture_df['source'] = 'accenture'
dyson_df['source'] = 'dyson'

# %%
df1 = pd.concat([walmart_df,accenture_df,dyson_df])
df1.to_csv('../datasets/extra_reviews_p1.csv', index = False)

# %%
url = 'https://www.glassdoor.sg/Interview/Wells-Fargo-Interview-Questions-E8876.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,71]
max_page = 711            # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    wellsfargo_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for Wells Fargo interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 710
# 2 of 710
# 3 of 710
# 4 of 710
# 5 of 710
# 6 of 710
# 7 of 710
# 8 of 710
# 9 of 710
# 10 of 710
# 11 of 710
# 12 of 710
# 13 of 710
# 14 of 710
# 15 of 710
# 16 of 710
# 17 of 710
# 18 of 710
# 19 of 710
# 20 of 710
# 21 of 710
# 22 of 710
# 23 of 710
# 24 of 710
# 25 of 710
# 26 of 710
# 27 of 710
# 28 of 710
# 29 of 710
# 30 of 710
# 31 of 710
# 32 of 710
# 33 of 710
# 34 of 710
# 35 of 710
# 36 of 710
# Pause to rest. Run time : 4.03 minutes
#
# Scraping page :
# 37 of 710
# 38 of 710
# 39 of 710
# 40 of 710
# 41 of 710
# 42 of 710
# 43 of 710
# 44 of 710
# 45 of 710
# 46 of 710
# 47 of 710
# 48 of 710
# 49 of 710
# 50 of 710, Run time : 5.67 minutes
# 51 of 710
# 52 of 710
# 53 of 710
# 54 of 710
# 55 of 710
# 56 of 710
# 57 of 710
# 58 of 710
# 59 of 710
# 60 of 710
# 61 of 710
# 62 of 710
# 63 of 710
# 64 of 710
# 65 of 710
# 66 of 710
# 67 of 710
# 68 of 710
# 69 of 710
# 70 of 710
# Pause to rest. Run time : 8.02 minutes
#
# Scraping page :
# 71 of 710
# 72 of 710
# 73 of 710
# Pause to rest. Run time : 8.41 minutes
#
# Scraping page :
# 74 of 710
# 75 of 710
# 575 of 710
# 576 of 710
# 577 of 710
# 578 of 710
# 579 of 710
# 580 of 710
# 581 of 710
# 582 of 710
# 583 of 710
# 584 of 710
# 585 of 710
# 586 of 710
# 587 of 710
# 588 of 710
# 589 of 710
# 590 of 710
# 591 of 710
# Pause to rest. Run time : 69.58 minutes
#
# Scraping page :
# 592 of 710
# 593 of 710
# 594 of 710
# 595 of 710
# 596 of 710
# 597 of 710
# 598 of 710
# 599 of 710
# 600 of 710, Run time : 70.67 minutes
# 601 of 710
# 602 of 710
# 603 of 710
# 604 of 710
# 605 of 710
# 606 of 710
# Refreshing page 607...
# 607 of 710
# 608 of 710
# 609 of 710
# 610 of 710
# 611 of 710
# 612 of 710
# 613 of 710
# 614 of 710
# 615 of 710
# 616 of 710
# 617 of 710
# 618 of 710
# 619 of 710
# 620 of 710
# 621 of 710
# 622 of 710
# 623 of 710
# 624 of 710
# 625 of 710
# 626 of 710
# 627 of 710
# 628 of 710
# 629 of 710
# 630 of 710
# 631 of 710
# 632 of 710
# 633 of 710
# 634 of 710
# 635 of 710
# 636 of 710
# 637 of 710
# 638 of 710
# Pause to rest. Run time : 75.45 minutes
#
# Scraping page :
# 639 of 710
# 640 of 710
# 641 of 710
# 642 of 710
# 643 of 710
# 644 of 710
# 645 of 710
# 646 of 710
# 647 of 710
# 648 of 710
# 649 of 710
# 650 of 710, Run time : 77.02 minutes
# 651 of 710
# 652 of 710
# 653 of 710
# 654 of 710
# 655 of 710
# 656 of 710
# 657 of 710
# 658 of 710
# 659 of 710
# 660 of 710
# 661 of 710
# 662 of 710
# 663 of 710
# 664 of 710
# 665 of 710
# Pause to rest. Run time : 78.71 minutes
#
# Scraping page :
# 666 of 710
# 667 of 710
# 668 of 710
# 669 of 710
# 670 of 710
# 671 of 710
# 672 of 710
# 673 of 710
# 674 of 710
# 675 of 710
# 676 of 710
# 677 of 710
# 678 of 710
# 679 of 710
# 680 of 710
# 681 of 710
# 682 of 710
# 683 of 710
# 684 of 710
# 685 of 710
# 686 of 710
# 687 of 710
# 688 of 710
# 689 of 710
# 690 of 710
# 691 of 710
# 692 of 710
# 693 of 710
# 694 of 710
# 695 of 710
# 696 of 710
# 697 of 710
# 698 of 710
# 699 of 710
# 700 of 710, Run time : 82.73 minutes
# 701 of 710
# 702 of 710
# 703 of 710
# 704 of 710
# 705 of 710
# 706 of 710
# 707 of 710
# 708 of 710
# 709 of 710
# Pause to rest. Run time : 83.78 minutes
#
# Scraping page :
# 710 of 710
#
# Successfully scraped for Wells Fargo interviews.
# Total duration : 83.94 minutes

# %%
url = 'https://www.glassdoor.sg/Interview/Netflix-Interview-Questions-E11891.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,71]
max_page = 72            # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    netflix_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for Netflix interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 71
# 2 of 71
# 3 of 71
# 4 of 71
# 5 of 71
# 6 of 71
# 7 of 71
# 8 of 71
# 9 of 71
# 10 of 71
# 11 of 71
# 12 of 71
# 13 of 71
# 14 of 71
# 15 of 71
# 16 of 71
# 17 of 71
# 18 of 71
# 19 of 71
# 20 of 71
# 21 of 71
# 22 of 71
# 23 of 71
# 24 of 71
# 25 of 71
# 26 of 71
# 27 of 71
# 28 of 71
# 29 of 71
# 30 of 71
# 31 of 71
# 32 of 71
# 33 of 71
# 34 of 71
# 35 of 71
# 36 of 71
# Pause to rest. Run time : 4.06 minutes
#
# Scraping page :
# 37 of 71
# 38 of 71
# 39 of 71
# 40 of 71
# 41 of 71
# 42 of 71
# 43 of 71
# 44 of 71
# 45 of 71
# 46 of 71
# 47 of 71
# 48 of 71
# 49 of 71
# 50 of 71, Run time : 5.65 minutes
# 51 of 71
# 52 of 71
# 53 of 71
# 54 of 71
# 55 of 71
# 56 of 71
# 57 of 71
# 58 of 71
# 59 of 71
# 60 of 71
# 61 of 71
# 62 of 71
# 63 of 71
# 64 of 71
# 65 of 71
# 66 of 71
# 67 of 71
# 68 of 71
# 69 of 71
# 70 of 71
# Pause to rest. Run time : 7.65 minutes
#
# Scraping page :
# 71 of 71
#
# Successfully scraped for Netflix interviews.
# Total duration : 7.8 minutes

# %%
url = 'https://www.glassdoor.sg/Interview/Tesla-Interview-Questions-E43129.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,71]
max_page = 149            # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    tesla_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for Tesla interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 148
# 2 of 148
# 3 of 148
# 4 of 148
# 5 of 148
# 6 of 148
# 7 of 148
# 8 of 148
# 9 of 148
# 10 of 148
# 11 of 148
# 12 of 148
# 13 of 148
# 14 of 148
# 15 of 148
# 16 of 148
# 17 of 148
# 18 of 148
# 19 of 148
# 20 of 148
# 21 of 148
# 22 of 148
# 23 of 148
# 24 of 148
# 25 of 148
# 26 of 148
# 27 of 148
# 28 of 148
# 29 of 148
# 30 of 148
# 31 of 148
# 32 of 148
# 33 of 148
# 34 of 148
# 35 of 148
# 36 of 148
# Pause to rest. Run time : 4.18 minutes
#
# Scraping page :
# 37 of 148
# 38 of 148
# 39 of 148
# 40 of 148
# 41 of 148
# 42 of 148
# 43 of 148
# 44 of 148
# 45 of 148
# 46 of 148
# 47 of 148
# 48 of 148
# 49 of 148
# 50 of 148, Run time : 5.74 minutes
# 51 of 148
# 52 of 148
# 53 of 148
# 54 of 148
# 55 of 148
# 56 of 148
# 57 of 148
# 58 of 148
# 59 of 148
# 60 of 148
# 61 of 148
# 62 of 148
# 63 of 148
# 64 of 148
# 65 of 148
# 66 of 148
# 67 of 148
# 68 of 148
# 69 of 148
# 70 of 148
# Pause to rest. Run time : 7.9 minutes
#
# Scraping page :
# 71 of 148
# 72 of 148
# 73 of 148
# Pause to rest. Run time : 8.26 minutes
#
# Scraping page :
# 74 of 148
# 75 of 148
# 76 of 148
# 77 of 148
# 78 of 148
# 79 of 148
# 80 of 148
# 81 of 148
# 82 of 148
# 83 of 148
# 84 of 148
# 85 of 148
# 86 of 148
# 87 of 148
# 88 of 148
# 89 of 148
# 90 of 148
# 91 of 148
# 92 of 148
# 93 of 148
# 94 of 148
# 95 of 148
# 96 of 148
# 97 of 148
# 98 of 148
# 99 of 148
# 100 of 148, Run time : 11.3 minutes
# 101 of 148
# 102 of 148
# 103 of 148
# 104 of 148
# 105 of 148
# 106 of 148
# 107 of 148
# 108 of 148
# 109 of 148
# 110 of 148
# 111 of 148
# 112 of 148
# 113 of 148
# 114 of 148
# 115 of 148
# 116 of 148
# 117 of 148
# 118 of 148
# 119 of 148
# 120 of 148
# 121 of 148
# 122 of 148
# 123 of 148
# 124 of 148
# 125 of 148
# 126 of 148
# 127 of 148
# 128 of 148
# 129 of 148
# 130 of 148
# 131 of 148
# 132 of 148
# 133 of 148
# 134 of 148
# 135 of 148
# 136 of 148
# 137 of 148
# 138 of 148
# 139 of 148
# 140 of 148
# 141 of 148
# Pause to rest. Run time : 15.91 minutes
#
# Scraping page :
# 142 of 148
# 143 of 148
# 144 of 148
# 145 of 148
# 146 of 148
# 147 of 148
# Pause to rest. Run time : 16.69 minutes
#
# Scraping page :
# 148 of 148
#
# Successfully scraped for Tesla interviews.
# Total duration : 16.86 minutes

# %%
wellsfargo_df['source'] = 'wellsfargo'
netflix_df['source'] = 'netflix'
tesla_df['source'] = 'tesla'

# %%
df2 = pd.concat([wellsfargo_df,netflix_df,tesla_df])
df2.to_csv('../datasets/extra_reviews_p2.csv', index = False)

# %%
url = 'https://www.glassdoor.sg/Interview/J-P-Morgan-Interview-Questions-E145.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,71]
max_page = 819            # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    jpmorgan_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for JP Morgan interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 818
# 2 of 818
# 3 of 818
# 4 of 818
# 5 of 818
# 6 of 818
# 7 of 818
# 8 of 818
# 9 of 818
# 10 of 818
# 11 of 818
# 12 of 818
# 13 of 818
# 14 of 818
# 15 of 818
# 16 of 818
# 17 of 818
# 18 of 818
# 19 of 818
# 20 of 818
# 21 of 818
# 22 of 818
# 23 of 818
# 24 of 818
# 25 of 818
# 26 of 818
# 27 of 818
# 28 of 818
# 29 of 818
# 30 of 818
# 31 of 818
# 32 of 818
# 33 of 818
# 34 of 818
# 35 of 818
# 36 of 818
# Pause to rest. Run time : 4.19 minutes
#
# Scraping page :
# 37 of 818
# 38 of 818
# 39 of 818
# 40 of 818
# 41 of 818
# 42 of 818
# 43 of 818
# 44 of 818
# 45 of 818
# 46 of 818
# 47 of 818
# 48 of 818
# 49 of 818
# 50 of 818, Run time : 5.72 minutes
# 51 of 818
# 52 of 818
# 53 of 818
# 54 of 818
# 55 of 818
# 56 of 818
# 57 of 818
# 58 of 818
# 59 of 818
# 60 of 818
# 61 of 818
# 62 of 818
# 63 of 818
# 64 of 818
# 65 of 818
# 66 of 818
# 67 of 818
# 68 of 818
# 69 of 818
# 70 of 818
# Pause to rest. Run time : 7.74 minutes
#
# Scraping page :
# 71 of 818
# 72 of 818
# 73 of 818
# Pause to rest. Run time : 8.1 minutes
#
# Scraping page :
# 74 of 818
# 75 of 818
# 76 of 818
# 77 of 818
# 78 of 818
# 79 of 818
# 80 of 818
# 81 of 818
# 82 of 818
# 83 of 818
# 84 of 818
# 85 of 818
# 86 of 818
# 87 of 818
# 88 of 818
# 89 of 818
# 90 of 818
# 91 of 818
# 92 of 818
# 93 of 818
# 94 of 818
# 95 of 818
# 96 of 818
# 97 of 818
# 98 of 818
# 99 of 818
# 100 of 818, Run time : 11.01 minutes
# 101 of 818
# 102 of 818
# 103 of 818
# 104 of 818
# 105 of 818
# 106 of 818
# 107 of 818
# 108 of 818
# 109 of 818
# 110 of 818
# 111 of 818
# 112 of 818
# 113 of 818
# 114 of 818
# 115 of 818
# 116 of 818
# 117 of 818
# 118 of 818
# 119 of 818
# 120 of 818
# 121 of 818
# 122 of 818
# 123 of 818
# 124 of 818
# 125 of 818
# 628 of 818
# 629 of 818
# 630 of 818
# 631 of 818
# 632 of 818
# 633 of 818
# 634 of 818
# 635 of 818
# 636 of 818
# 637 of 818
# 638 of 818
# Pause to rest. Run time : 73.09 minutes
# Scraping page :
# 639 of 818
# 640 of 818
# 641 of 818
# 642 of 818
# 643 of 818
# 644 of 818
# 645 of 818
# 646 of 818
# 647 of 818
# 648 of 818
# 649 of 818
# 650 of 818, Run time : 74.5 minutes
# 651 of 818
# 652 of 818
# 653 of 818
# 654 of 818
# 655 of 818
# 656 of 818
# 657 of 818
# 658 of 818
# 659 of 818
# 660 of 818
# 661 of 818
# 662 of 818
# 663 of 818
# 664 of 818
# 665 of 818
# Pause to rest. Run time : 76.37 minutes
#
# Scraping page :
# 666 of 818
# 667 of 818
# 668 of 818
# 669 of 818
# 670 of 818
# 671 of 818
# 672 of 818
# 673 of 818
# 674 of 818
# 675 of 818
# 676 of 818
# 677 of 818
# 678 of 818
# 679 of 818
# 680 of 818
# 681 of 818
# 682 of 818
# 683 of 818
# 684 of 818
# 685 of 818
# 686 of 818
# 687 of 818
# 688 of 818
# 689 of 818
# 690 of 818
# 691 of 818
# 692 of 818
# 693 of 818
# 694 of 818
# 695 of 818
# 696 of 818
# 697 of 818
# 698 of 818
# 699 of 818
# 700 of 818, Run time : 80.99 minutes
# 701 of 818
# 702 of 818
# 703 of 818
# 704 of 818
# 705 of 818
# 706 of 818
# 707 of 818
# 708 of 818
# 709 of 818
# Pause to rest. Run time : 82.11 minutes
#
# Scraping page :
# 710 of 818
# 711 of 818
# 712 of 818
# 713 of 818
# 714 of 818
# 715 of 818
# 716 of 818
# 717 of 818
# 718 of 818
# 719 of 818
# 720 of 818
# 721 of 818
# 722 of 818
# 723 of 818
# 724 of 818
# 725 of 818
# 726 of 818
# 727 of 818
# 728 of 818
# 729 of 818
# 730 of 818
# 731 of 818
# 732 of 818
# 733 of 818
# 734 of 818
# 735 of 818
# 736 of 818
# 737 of 818
# 738 of 818
# 739 of 818
# Pause to rest. Run time : 85.86 minutes
#
# Scraping page :
# 740 of 818
# 741 of 818
# 742 of 818
# 743 of 818
# 744 of 818
# 745 of 818
# 746 of 818
# 747 of 818
# 748 of 818
# 749 of 818
# 750 of 818, Run time : 87.18 minutes
# 751 of 818
# 752 of 818
# 753 of 818
# 754 of 818
# 755 of 818
# 756 of 818
# 757 of 818
# 758 of 818
# 759 of 818
# 760 of 818
# 761 of 818
# 762 of 818
# 763 of 818
# 764 of 818
# 765 of 818
# 766 of 818
# 767 of 818
# 768 of 818
# 769 of 818
# 770 of 818
# 771 of 818
# 772 of 818
# 773 of 818
# 774 of 818
# 775 of 818
# 776 of 818
# 777 of 818
# 778 of 818
# 779 of 818
# 780 of 818
# Pause to rest. Run time : 90.81 minutes
#
# Scraping page :
# 781 of 818
# 782 of 818
# 783 of 818
# 784 of 818
# 785 of 818
# 786 of 818
# 787 of 818
# 788 of 818
# 789 of 818
# 790 of 818
# 791 of 818
# 792 of 818
# 793 of 818
# 794 of 818
# 795 of 818
# 796 of 818
# 797 of 818
# 798 of 818
# 799 of 818
# 800 of 818, Run time : 93.33 minutes
# 801 of 818
# 802 of 818
# 803 of 818
# 804 of 818
# 805 of 818
# 806 of 818
# 807 of 818
# 808 of 818
# 809 of 818
# 810 of 818
# 811 of 818
# 812 of 818
# 813 of 818
# Pause to rest. Run time : 94.94 minutes
#
# Scraping page :
# 814 of 818
# 815 of 818
# 816 of 818
# 817 of 818
# 818 of 818
#
# Successfully scraped for JP Morgan interviews.
# Total duration : 95.56 minutes

# %%
url = 'https://www.glassdoor.sg/Interview/Bloomberg-L-P-Interview-Questions-E3096.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,71]
max_page = 584            # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    bloomberg_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for Bloomberg interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 583
# 2 of 583
# 3 of 583
# 4 of 583
# 5 of 583
# 6 of 583
# 7 of 583
# 8 of 583
# 9 of 583
# 10 of 583
# 11 of 583
# 12 of 583
# 13 of 583
# 14 of 583
# 15 of 583
# 16 of 583
# 17 of 583
# 18 of 583
# 19 of 583
# 20 of 583
# 21 of 583
# 22 of 583
# 23 of 583
# 24 of 583
# 25 of 583
# 26 of 583
# 27 of 583
# 28 of 583
# 29 of 583
# 30 of 583
# 31 of 583
# 32 of 583
# 33 of 583
# 34 of 583
# 35 of 583
# 36 of 583
# Pause to rest. Run time : 3.12 minutes
#
# Scraping page :
# 37 of 583
# 38 of 583
# 39 of 583
# 40 of 583
# 41 of 583
# 42 of 583
# 43 of 583
# 44 of 583
# 45 of 583
# 46 of 583
# 47 of 583
# 48 of 583
# 49 of 583
# 50 of 583, Run time : 4.3 minutes
# 51 of 583
# 52 of 583
# 53 of 583
# 54 of 583
# 55 of 583
# 56 of 583
# 57 of 583
# 58 of 583
# 59 of 583
# 60 of 583
# 61 of 583
# 62 of 583
# 63 of 583
# 64 of 583
# 65 of 583
# 66 of 583
# 67 of 583
# 68 of 583
# 69 of 583
# 70 of 583
# Pause to rest. Run time : 5.88 minutes
#
# Scraping page :
# 71 of 583
# 72 of 583
# 73 of 583
# Pause to rest. Run time : 6.15 minutes
#
# Scraping page :
# 74 of 583
# 75 of 583
# 76 of 583
# 77 of 583
# 78 of 583
# 79 of 583
# 80 of 583
# 81 of 583
# 82 of 583
# 83 of 583
# 84 of 583
# 85 of 583
# 86 of 583
# 87 of 583
# 88 of 583
# 89 of 583
# 90 of 583
# 91 of 583
# 92 of 583
# 93 of 583
# 94 of 583
# 95 of 583
# 96 of 583
# 97 of 583
# 98 of 583
# 99 of 583
# 100 of 583, Run time : 8.72 minutes
# 101 of 583
# 102 of 583
# 103 of 583
# 104 of 583
# 105 of 583
# 106 of 583
# 107 of 583
# 108 of 583
# 109 of 583
# 110 of 583
# 111 of 583
# 112 of 583
# 113 of 583
# 114 of 583
# 115 of 583
# 116 of 583
# 117 of 583
# 118 of 583
# 119 of 583
# 120 of 583
# 121 of 583
# 122 of 583
# 123 of 583
# 124 of 583
# 125 of 583
# 126 of 583
# 127 of 583
# 128 of 583
# 129 of 583
# 130 of 583
# 131 of 583
# 132 of 583
# 133 of 583
# 134 of 583
# 135 of 583
# 136 of 583
# 137 of 583
# 138 of 583
# 139 of 583
# 140 of 583
# 141 of 583
# Pause to rest. Run time : 12.08 minutes
#
# Scraping page :
# 142 of 583
# 143 of 583
# 144 of 583
# 145 of 583
# 146 of 583
# 147 of 583
# Pause to rest. Run time : 12.6 minutes
#
# Scraping page :
# 148 of 583
# 149 of 583
# 150 of 583, Run time : 12.88 minutes
# 151 of 583
# 152 of 583
# 153 of 583
# 154 of 583
# 155 of 583
# 156 of 583
# 157 of 583
# 158 of 583
# 159 of 583
# 160 of 583
# 161 of 583
# 162 of 583
# 163 of 583
# 164 of 583
# 165 of 583
# 166 of 583
# 167 of 583
# 168 of 583
# 169 of 583
# 170 of 583
# 171 of 583
# 172 of 583
# 173 of 583
# 174 of 583
# 175 of 583
# 176 of 583
# 177 of 583
# 178 of 583
# 179 of 583
# 180 of 583
# 181 of 583
# 182 of 583
# 183 of 583
# 184 of 583
# 185 of 583
# 186 of 583
# 187 of 583
# 188 of 583
# 189 of 583
# 190 of 583
# 191 of 583
# 192 of 583
# 193 of 583
# 194 of 583
# 195 of 583
# 196 of 583
# 197 of 583
# 198 of 583
# 199 of 583
# 200 of 583, Run time : 16.81 minutes
# 201 of 583
# 202 of 583
# 203 of 583
# 204 of 583
# 205 of 583
# 206 of 583
# 207 of 583
# 208 of 583
# 209 of 583
# 210 of 583
# 211 of 583
# 212 of 583
# Pause to rest. Run time : 17.75 minutes
#
# Scraping page :
# 213 of 583
# 214 of 583
# 215 of 583
# 216 of 583
# 217 of 583
# 218 of 583
# 219 of 583
# 220 of 583
# 221 of 583
# Pause to rest. Run time : 18.49 minutes
#
# Scraping page :
# 222 of 583
# 223 of 583
# 224 of 583
# 225 of 583
# 226 of 583
# 227 of 583
# 228 of 583
# 229 of 583
# 230 of 583
# 231 of 583
# 232 of 583
# 233 of 583
# 234 of 583
# 235 of 583
# 236 of 583
# 237 of 583
# 238 of 583
# 239 of 583
# 240 of 583
# 241 of 583
# 242 of 583
# 243 of 583
# 244 of 583
# 245 of 583
# 246 of 583
# 247 of 583
# 248 of 583
# 249 of 583
# 250 of 583, Run time : 21.07 minutes
# 251 of 583
# 252 of 583
# 253 of 583
# 254 of 583
# 255 of 583
# 256 of 583
# 257 of 583
# 258 of 583
# 259 of 583
# 260 of 583
# 261 of 583
# 262 of 583
# 263 of 583
# 264 of 583
# 265 of 583
# 266 of 583
# 267 of 583
# 268 of 583
# 269 of 583
# 270 of 583
# 271 of 583
# 272 of 583
# 273 of 583
# 274 of 583
# 275 of 583
# 276 of 583
# 277 of 583
# 278 of 583
# 279 of 583
# 280 of 583
# 281 of 583
# 282 of 583
# 283 of 583
# Pause to rest. Run time : 24.04 minutes
#
# Scraping page :
# 284 of 583
# 285 of 583
# 286 of 583
# 287 of 583
# 288 of 583
# 289 of 583
# 290 of 583
# 291 of 583
# 292 of 583
# 293 of 583
# 294 of 583
# 295 of 583
# Pause to rest. Run time : 25.46 minutes
#
# Scraping page :
# 296 of 583
# 297 of 583
# 298 of 583
# 299 of 583
# 300 of 583, Run time : 26.06 minutes
# 301 of 583
# 302 of 583
# 303 of 583
# 304 of 583
# 305 of 583
# 306 of 583
# 307 of 583
# 308 of 583
# 309 of 583
# 310 of 583
# 311 of 583
# 312 of 583
# 313 of 583
# 314 of 583
# 315 of 583
# 316 of 583
# 317 of 583
# 318 of 583
# 319 of 583
# 320 of 583
# 321 of 583
# 322 of 583
# 323 of 583
# 324 of 583
# 325 of 583
# 326 of 583
# 327 of 583
# 328 of 583
# 329 of 583
# 330 of 583
# 331 of 583
# 332 of 583
# 333 of 583
# 334 of 583
# 335 of 583
# 336 of 583
# 337 of 583
# 338 of 583
# 339 of 583
# 340 of 583
# 341 of 583
# 342 of 583
# 343 of 583
# 344 of 583
# 345 of 583
# 346 of 583
# 347 of 583
# 348 of 583
# 349 of 583
# 350 of 583, Run time : 30.28 minutes
# 351 of 583
# 352 of 583
# 353 of 583
# 354 of 583
# Pause to rest. Run time : 30.6 minutes
#
# Scraping page :
# 355 of 583
# 356 of 583
# 357 of 583
# 358 of 583
# 359 of 583
# 360 of 583
# 361 of 583
# 362 of 583
# 363 of 583
# 364 of 583
# 365 of 583
# 366 of 583
# 367 of 583
# 368 of 583
# 369 of 583
# Pause to rest. Run time : 31.96 minutes
#
# Scraping page :
# 370 of 583
# 371 of 583
# 372 of 583
# 373 of 583
# 374 of 583
# 375 of 583
# 376 of 583
# 377 of 583
# 378 of 583
# 379 of 583
# 380 of 583
# 381 of 583
# 382 of 583
# 383 of 583
# 384 of 583
# 385 of 583
# 386 of 583
# 387 of 583
# 388 of 583
# 389 of 583
# 390 of 583
# 391 of 583
# 392 of 583
# 393 of 583
# 394 of 583
# 395 of 583
# 396 of 583
# 397 of 583
# 398 of 583
# 399 of 583
# 400 of 583, Run time : 34.68 minutes
# 401 of 583
# 402 of 583
# 403 of 583
# 404 of 583
# 405 of 583
# 406 of 583
# 407 of 583
# 408 of 583
# 409 of 583
# 410 of 583
# 411 of 583
# 412 of 583
# 413 of 583
# 414 of 583
# 415 of 583
# 416 of 583
# 417 of 583
# 418 of 583
# 419 of 583
# 420 of 583
# 421 of 583
# 422 of 583
# 423 of 583
# 424 of 583
# 425 of 583
# Pause to rest. Run time : 36.77 minutes
#
# Scraping page :
# 426 of 583
# 427 of 583
# 428 of 583
# 429 of 583
# 430 of 583
# 431 of 583
# 432 of 583
# 433 of 583
# 434 of 583
# 435 of 583
# 436 of 583
# 437 of 583
# 438 of 583
# 439 of 583
# 440 of 583
# 441 of 583
# 442 of 583
# 443 of 583
# Pause to rest. Run time : 38.34 minutes
#
# Scraping page :
# 444 of 583
# 445 of 583
# 446 of 583
# 447 of 583
# 448 of 583
# 449 of 583
# 450 of 583, Run time : 38.93 minutes
# 451 of 583
# 452 of 583
# 453 of 583
# 454 of 583
# 455 of 583
# 456 of 583
# 457 of 583
# 458 of 583
# 459 of 583
# 460 of 583
# 461 of 583
# 462 of 583
# 463 of 583
# 464 of 583
# 465 of 583
# 466 of 583
# 467 of 583
# 468 of 583
# 469 of 583
# 470 of 583
# 471 of 583
# 472 of 583
# 473 of 583
# 474 of 583
# 475 of 583
# 476 of 583
# 477 of 583
# 478 of 583
# 479 of 583
# 480 of 583
# 481 of 583
# 482 of 583
# 483 of 583
# 484 of 583
# 485 of 583
# 486 of 583
# 487 of 583
# 488 of 583
# 489 of 583
# 490 of 583
# 491 of 583
# 492 of 583
# 493 of 583
# 494 of 583
# 495 of 583
# 496 of 583
# Pause to rest. Run time : 43.08 minutes
#
# Scraping page :
# 497 of 583
# 498 of 583
# 499 of 583
# 500 of 583, Run time : 43.43 minutes
# 501 of 583
# 502 of 583
# 503 of 583
# 504 of 583
# 505 of 583
# 506 of 583
# 507 of 583
# 508 of 583
# 509 of 583
# 510 of 583
# 511 of 583
# 512 of 583
# 513 of 583
# 514 of 583
# 515 of 583
# 516 of 583
# 517 of 583
# Pause to rest. Run time : 44.96 minutes
#
# Scraping page :
# 518 of 583
# 519 of 583
# 520 of 583
# 521 of 583
# 522 of 583
# 523 of 583
# 524 of 583
# 525 of 583
# 526 of 583
# 527 of 583
# 528 of 583
# 529 of 583
# 530 of 583
# 531 of 583
# 532 of 583
# 533 of 583
# 534 of 583
# 535 of 583
# 536 of 583
# 537 of 583
# 538 of 583
# 539 of 583
# 540 of 583
# 541 of 583
# 542 of 583
# 543 of 583
# 544 of 583
# 545 of 583
# 546 of 583
# 547 of 583
# 548 of 583
# 549 of 583
# 550 of 583, Run time : 48.51 minutes
# 551 of 583
# 552 of 583
# 553 of 583
# 554 of 583
# 555 of 583
# 556 of 583
# 557 of 583
# 558 of 583
# 559 of 583
# 560 of 583
# 561 of 583
# 562 of 583
# 563 of 583
# 564 of 583
# 565 of 583
# 566 of 583
# 567 of 583
# Pause to rest. Run time : 49.93 minutes
#
# Scraping page :
# 568 of 583
# 569 of 583
# 570 of 583
# 571 of 583
# 572 of 583
# 573 of 583
# 574 of 583
# 575 of 583
# 576 of 583
# 577 of 583
# 578 of 583
# 579 of 583
# 580 of 583
# 581 of 583
# 582 of 583
# 583 of 583
#
# Successfully scraped for Bloomberg interviews.
# Total duration : 51.27 minutes

# %%
url = 'https://www.glassdoor.sg/Interview/LinkedIn-Interview-Questions-E34865.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,71]
max_page = 187            # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    linkedin_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name

print(f'\nSuccessfully scraped for linkedin interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 186
# 2 of 186
# 3 of 186
# 4 of 186
# 5 of 186
# 6 of 186
# 7 of 186
# 8 of 186
# 9 of 186
# 10 of 186
# 11 of 186
# 12 of 186
# 13 of 186
# 14 of 186
# 15 of 186
# 16 of 186
# 17 of 186
# 18 of 186
# 19 of 186
# 20 of 186
# 21 of 186
# 22 of 186
# 23 of 186
# 24 of 186
# 25 of 186
# 26 of 186
# 27 of 186
# 28 of 186
# 29 of 186
# 30 of 186
# 31 of 186
# 32 of 186
# 33 of 186
# 34 of 186
# 35 of 186
# 36 of 186
# Pause to rest. Run time : 4.09 minutes
#
# Scraping page :
# 37 of 186
# 38 of 186
# 39 of 186
# 40 of 186
# 41 of 186
# 42 of 186
# 43 of 186
# 44 of 186
# 45 of 186
# 46 of 186
# 47 of 186
# 48 of 186
# 49 of 186
# 50 of 186, Run time : 5.68 minutes
# 51 of 186
# 52 of 186
# 53 of 186
# 54 of 186
# 55 of 186
# 56 of 186
# 57 of 186
# 58 of 186
# 59 of 186
# 60 of 186
# 61 of 186
# 62 of 186
# 63 of 186
# 64 of 186
# 65 of 186
# 66 of 186
# 67 of 186
# 68 of 186
# 69 of 186
# 70 of 186
# Pause to rest. Run time : 7.84 minutes
#
# Scraping page :
# 71 of 186
# 72 of 186
# 73 of 186
# Pause to rest. Run time : 8.23 minutes
#
# Scraping page :
# 74 of 186
# 75 of 186
# 76 of 186
# 77 of 186
# 78 of 186
# 79 of 186
# 80 of 186
# 81 of 186
# 82 of 186
# 83 of 186
# 84 of 186
# 85 of 186
# 86 of 186
# 87 of 186
# 88 of 186
# 89 of 186
# 90 of 186
# 91 of 186
# 92 of 186
# 93 of 186
# 94 of 186
# 95 of 186
# 96 of 186
# 97 of 186
# 98 of 186
# 99 of 186
# 100 of 186, Run time : 11.59 minutes
# 101 of 186
# 102 of 186
# 103 of 186
# 104 of 186
# 105 of 186
# 106 of 186
# 107 of 186
# 108 of 186
# 109 of 186
# 110 of 186
# 111 of 186
# 112 of 186
# 113 of 186
# 114 of 186
# 115 of 186
# 116 of 186
# 117 of 186
# 118 of 186
# 119 of 186
# 120 of 186
# 121 of 186
# 122 of 186
# 123 of 186
# 124 of 186
# 125 of 186
# 126 of 186
# 127 of 186
# 128 of 186
# 129 of 186
# 130 of 186
# 131 of 186
# 132 of 186
# 133 of 186
# 134 of 186
# 135 of 186
# 136 of 186
# 137 of 186
# 138 of 186
# 139 of 186
# 140 of 186
# 141 of 186
# Pause to rest. Run time : 16.25 minutes
#
# Scraping page :
# 142 of 186
# 143 of 186
# 144 of 186
# 145 of 186
# 146 of 186
# 147 of 186
# Pause to rest. Run time : 16.99 minutes
#
# Scraping page :
# 148 of 186
# 149 of 186
# 150 of 186, Run time : 17.45 minutes
# 151 of 186
# 152 of 186
# 153 of 186
# 154 of 186
# 155 of 186
# 156 of 186
# 157 of 186
# 158 of 186
# 159 of 186
# 160 of 186
# 161 of 186
# 162 of 186
# 163 of 186
# 164 of 186
# 165 of 186
# 166 of 186
# 167 of 186
# 168 of 186
# 169 of 186
# 170 of 186
# 171 of 186
# 172 of 186
# 173 of 186
# 174 of 186
# 175 of 186
# 176 of 186
# 177 of 186
# 178 of 186
# 179 of 186
# 180 of 186
# 181 of 186
# 182 of 186
# 183 of 186
# 184 of 186
# 185 of 186
# 186 of 186
#
# Successfully scraped for linkedin interviews.
# Total duration : 21.28 minutes

# %%
jpmorgan_df['source'] = 'jpmorgan'
bloomberg_df['source'] = 'bloomberg'
linkedin_df['source'] = 'linkedin'

# %%
df3 = pd.concat([jpmorgan_df,bloomberg_df,linkedin_df])
df3.to_csv('../datasets/extra_reviews_p3.csv', index = False)

# %%
df = pd.concat([df1,df2,df3])

# %%
df.to_csv('../datasets/extrareviews.csv', index = False)

# %%
df['interview'].fillna('', inplace = True)
df['question'].fillna('', inplace = True)
# fill all nan with ''

# %%
df = df[df['experience'] == 'Negative Experience']

# %%
df['experience'] = df['experience'].apply(lambda exp : 1 if exp == 'Positive Experience' else 0)
# Out:
# <ipython-input-5-eee345e0123d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['experience'] = df['experience'].apply(lambda exp : 1 if exp == 'Positive Experience' else 0)

# %%
df['length'] = df['interview'].apply(len)
df = df[df['length']!=0]
# Out:
# <ipython-input-6-875fdd15f382>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['length'] = df['interview'].apply(len)

# %%
df = df[(df.length <= 1000) & (df.length >= 100)]

# %%
df.rename(columns = {'experience' : 'target_variable'}, inplace = True)

# %%
df.to_csv('../datasets/badreviewsonly.csv', index = False)

# %%
df.target_variable.value_counts()
# Out:
# 0    4394
# Name: target_variable, dtype: int64

# %%
df
# Out:
#                                                interview  \
# 1      1 phone and then 1 video interview with 2 peop...
# 15     Applied online and got called a week later. Ma...
# 129    Went in for interview at Neighborhood Walmart ...
# 145    Had to go through a month of interviews. First...
# 151    no interview was made as temp if you showed up...
# ...                                                  ...
# 50935  Some of the interview questions were decent (e...
# 50952  I have a very negative impression of LinkedIn ...
# 50958  Initially contacted by LinkedIn on their site....
# 50961  I was contacted almost immediately after apply...
# 50978  I applied in July, took them a month to call m...
#
#                                                 question           offer  \
# 1       Tell me about a time you had to give feedback...        No Offer
# 15                                                        Accepted Offer
# 129     What are your expectations? Do you have any q...  Declined Offer
# 145         What motivated you to apply for this job?           No Offer
# 151     no questions asked online application process     Accepted Offer
# ...                                                  ...             ...
# 50935                Intersection of 2 number arrays.           No Offer
# 50952   Data structures, algorithms, language gotchas...        No Offer
# 50958   Are you an introvert or an extrovert & what i...        No Offer
# 50961      They asked me about my role as a recruiter           No Offer
# 50978   If you could develop one skill you do not alr...        No Offer
#
#        target_variable         difficulty    source  length
# 1                    0     Easy Interview   walmart     244
# 15                   0     Easy Interview   walmart     160
# 129                  0     Easy Interview   walmart     367
# 145                  0  Average Interview   walmart     179
# 151                  0     Easy Interview   walmart     170
# ...                ...                ...       ...     ...
# 50935                0  Average Interview  linkedin     494
# 50952                0  Average Interview  linkedin     460
# 50958                0  Average Interview  linkedin     487
# 50961                0  Average Interview  linkedin     484
# 50978                0  Average Interview  linkedin     971
#
# [4394 rows x 7 columns]
