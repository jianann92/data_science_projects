# %%
# Importing libraries

import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from matplotlib.pyplot import get_cmap

import plotly.express as px
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import regex as re
import requests
from lxml import html
import getpass
from googletrans import Translator
import unicodedata
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jiana\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jiana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import random

opts = Options()
opts.add_argument('user-agent=polar-bear 3.0')
opts.add_argument("--headless")

# %%
email = getpass.getpass('Email : ')
password = getpass.getpass('Password : ')

try: 
    driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts) 
    driver.get('https://www.glassdoor.sg/index.htm') 
    driver.implicitly_wait(15)
    
    loginpage = driver.find_element_by_xpath('//*[@id="TopNav"]/nav/div/div/div[4]/div[1]/a')
    loginpage.click()

    loginBox = driver.find_element_by_xpath('//*[@id="userEmail"]') 
    loginBox.send_keys(email)
    
    passWordBox = driver.find_element_by_xpath('//*[@id="userPassword"]')
    passWordBox.send_keys(password)
    
    signin = driver.find_element_by_xpath('//*[@id="LoginModal"]/div/div/div[2]/div[2]/div[2]/div/div/div/div[3]/form/div[3]/div[1]/button')
    signin.click()
    
    print('Login Successful!')

except:
    print('Login Failed')
# Out:
# Email : ········
# Password : ········
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [C:\Users\jiana\.wdm\drivers\chromedriver\win32\86.0.4240.22\chromedriver.exe] found in cache
# <ipython-input-7-4fcec7ff2489>:5: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts)
# Login Successful!

# %%
url = 'https://www.glassdoor.sg/Interview/Apple-Interview-Questions-E1138.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,73]
max_page = 805             # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(3,4))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(5,8))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    apple_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name
    apple_df.to_csv('../datasets/apple.csv', index = False)

print(f'\nSuccessfully scraped for Apple interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 804
# 2 of 804
# 3 of 804
# 4 of 804
# 5 of 804
# 6 of 804
# 7 of 804
# 8 of 804
# 9 of 804
# 10 of 804
# 11 of 804
# 12 of 804
# 13 of 804
# 14 of 804
# 15 of 804
# 16 of 804
# 17 of 804
# 18 of 804
# 19 of 804
# 20 of 804
# 21 of 804
# 22 of 804
# 23 of 804
# 24 of 804
# 25 of 804
# 26 of 804
# 27 of 804
# 28 of 804
# 29 of 804
# 30 of 804
# 31 of 804
# 32 of 804
# 33 of 804
# 34 of 804
# 35 of 804
# 36 of 804
# Pause to rest. Run time : 9.06 minutes
#
# Scraping page :
# 37 of 804
# 38 of 804
# 39 of 804
# 40 of 804
# 41 of 804
# 42 of 804
# 43 of 804
# 44 of 804
# 45 of 804
# 46 of 804
# 47 of 804
# 48 of 804
# 49 of 804
# 50 of 804, Run time : 12.78 minutes
# 51 of 804
# 52 of 804
# 53 of 804
# 54 of 804
# 55 of 804
# 56 of 804
# 57 of 804
# 58 of 804
# 59 of 804
# 60 of 804
# 61 of 804
# 62 of 804
# 63 of 804
# 64 of 804
# 65 of 804
# 66 of 804
# 67 of 804
# 68 of 804
# 69 of 804
# 70 of 804
# 71 of 804
# 72 of 804
# Pause to rest. Run time : 18.2 minutes
#
# Scraping page :
# 73 of 804
# Pause to rest. Run time : 18.46 minutes
#
# Scraping page :
# 74 of 804
# 75 of 804
# 76 of 804
# 77 of 804
# 78 of 804
# 79 of 804
# 80 of 804
# 81 of 804
# 82 of 804
# 83 of 804
# 84 of 804
# 85 of 804
# 86 of 804
# 87 of 804
# 88 of 804
# 89 of 804
# 90 of 804
# 91 of 804
# 92 of 804
# 93 of 804
# 94 of 804
# 95 of 804
# 96 of 804
# 97 of 804
# 98 of 804
# 99 of 804
# 100 of 804, Run time : 25.7 minutes
# 101 of 804
# 102 of 804
# 103 of 804
# 104 of 804
# 105 of 804
# 106 of 804
# 107 of 804
# 108 of 804
# 109 of 804
# 110 of 804
# 111 of 804
# 112 of 804
# 113 of 804
# 114 of 804
# 115 of 804
# 116 of 804
# 117 of 804
# 118 of 804
# 119 of 804
# 120 of 804
# 121 of 804
# 122 of 804
# 123 of 804
# 124 of 804
# 125 of 804
# 126 of 804
# 127 of 804
# 128 of 804
# 129 of 804
# 130 of 804
# 131 of 804
# 132 of 804
# 133 of 804
# 134 of 804
# 135 of 804
# 136 of 804
# 137 of 804
# 138 of 804
# 139 of 804
# 140 of 804
# 141 of 804
# 142 of 804
# 143 of 804
# 144 of 804
# 145 of 804
# Pause to rest. Run time : 33.71 minutes
#
# Scraping page :
# 146 of 804
# 147 of 804
# Pause to rest. Run time : 34.08 minutes
#
# Scraping page :
# 148 of 804
# 149 of 804
# 150 of 804, Run time : 34.52 minutes
# 151 of 804
# 152 of 804
# 153 of 804
# 154 of 804
# 155 of 804
# 156 of 804
# 157 of 804
# 158 of 804
# 159 of 804
# 160 of 804
# 161 of 804
# 162 of 804
# 163 of 804
# 164 of 804
# 165 of 804
# 166 of 804
# 167 of 804
# 168 of 804
# 169 of 804
# 170 of 804
# 171 of 804
# 172 of 804
# 173 of 804
# 174 of 804
# 175 of 804
# 176 of 804
# 177 of 804
# 178 of 804
# 179 of 804
# 180 of 804
# 181 of 804
# 182 of 804
# 183 of 804
# 184 of 804
# 185 of 804
# 186 of 804
# 187 of 804
# 188 of 804
# 189 of 804
# 190 of 804
# 191 of 804
# 192 of 804
# 193 of 804
# 194 of 804
# 195 of 804
# 196 of 804
# 197 of 804
# 198 of 804
# 199 of 804
# 200 of 804, Run time : 42.36 minutes
# 201 of 804
# 202 of 804
# 203 of 804
# 204 of 804
# 205 of 804
# 206 of 804
# 207 of 804
# 208 of 804
# 209 of 804
# 210 of 804
# 211 of 804
# 212 of 804
# 213 of 804
# 214 of 804
# 215 of 804
# 216 of 804
# 217 of 804
# 218 of 804
# Pause to rest. Run time : 44.97 minutes
#
# Scraping page :
# 219 of 804
# 220 of 804
# 221 of 804
# Pause to rest. Run time : 45.55 minutes
#
# Scraping page :
# 222 of 804
# 223 of 804
# 224 of 804
# 225 of 804
# 226 of 804
# 227 of 804
# 228 of 804
# 229 of 804
# 230 of 804
# 231 of 804
# 232 of 804
# 233 of 804
# 234 of 804
# 235 of 804
# 236 of 804
# 237 of 804
# 238 of 804
# 239 of 804
# 240 of 804
# 241 of 804
# 242 of 804
# 243 of 804
# 244 of 804
# 245 of 804
# 246 of 804
# 247 of 804
# 248 of 804
# 249 of 804
# 250 of 804, Run time : 50.61 minutes
# 251 of 804
# 252 of 804
# 253 of 804
# 254 of 804
# 255 of 804
# 256 of 804
# 257 of 804
# 258 of 804
# 259 of 804
# 260 of 804
# 261 of 804
# 262 of 804
# 263 of 804
# 264 of 804
# 265 of 804
# 266 of 804
# 267 of 804
# 268 of 804
# 269 of 804
# 270 of 804
# 271 of 804
# 272 of 804
# 273 of 804
# 274 of 804
# 275 of 804
# 276 of 804
# 277 of 804
# 278 of 804
# 279 of 804
# 280 of 804
# 281 of 804
# 282 of 804
# 283 of 804
# 284 of 804
# 285 of 804
# 286 of 804
# 287 of 804
# 288 of 804
# 289 of 804
# 290 of 804
# 291 of 804
# Pause to rest. Run time : 56.34 minutes
#
# Scraping page :
# 292 of 804
# 293 of 804
# 294 of 804
# 295 of 804
# Pause to rest. Run time : 57.14 minutes
#
# Scraping page :
# 296 of 804
# 297 of 804
# 298 of 804
# 299 of 804
# 300 of 804, Run time : 58.37 minutes
# 301 of 804
# 302 of 804
# 303 of 804
# 304 of 804
# 305 of 804
# 306 of 804
# 307 of 804
# 308 of 804
# 309 of 804
# 310 of 804
# 311 of 804
# 312 of 804
# 313 of 804
# 314 of 804
# 315 of 804
# 316 of 804
# 317 of 804
# 318 of 804
# 319 of 804
# 320 of 804
# 321 of 804
# 322 of 804
# 323 of 804
# 324 of 804
# 325 of 804
# 326 of 804
# 327 of 804
# 328 of 804
# 329 of 804
# 330 of 804
# 331 of 804
# 332 of 804
# 333 of 804
# 334 of 804
# 335 of 804
# 336 of 804
# 337 of 804
# 338 of 804
# 339 of 804
# 340 of 804
# 341 of 804
# 342 of 804
# 343 of 804
# 344 of 804
# 345 of 804
# 346 of 804
# 347 of 804
# 348 of 804
# 349 of 804
# 350 of 804, Run time : 66.35 minutes
# 351 of 804
# 352 of 804
# 353 of 804
# 354 of 804
# 355 of 804
# 356 of 804
# 357 of 804
# 358 of 804
# 359 of 804
# 360 of 804
# 361 of 804
# 362 of 804
# 363 of 804
# 364 of 804
# Pause to rest. Run time : 68.11 minutes
#
# Scraping page :
# Refreshing page 365...
# Refreshing page 365...
# 365 of 804
# 366 of 804
# 367 of 804
# 368 of 804
# 369 of 804
# Pause to rest. Run time : 69.28 minutes
#
# Scraping page :
# 370 of 804
# 371 of 804
# 372 of 804
# 373 of 804
# 374 of 804
# 375 of 804
# 376 of 804
# 377 of 804
# 378 of 804
# 379 of 804
# 380 of 804
# 381 of 804
# 382 of 804
# 383 of 804
# 384 of 804
# 385 of 804
# 386 of 804
# 387 of 804
# 388 of 804
# 389 of 804
# 390 of 804
# 391 of 804
# 392 of 804
# 393 of 804
# 394 of 804
# 395 of 804
# 396 of 804
# 397 of 804
# 398 of 804
# 399 of 804
# 400 of 804, Run time : 73.45 minutes
# 401 of 804
# 402 of 804
# 403 of 804
# 404 of 804
# 405 of 804
# 406 of 804
# 407 of 804
# 408 of 804
# 409 of 804
# 410 of 804
# 411 of 804
# 412 of 804
# 413 of 804
# 414 of 804
# 415 of 804
# 416 of 804
# 417 of 804
# 418 of 804
# 419 of 804
# 420 of 804
# 421 of 804
# 422 of 804
# 423 of 804
# 424 of 804
# 425 of 804
# 426 of 804
# 427 of 804
# 428 of 804
# 429 of 804
# 430 of 804
# 431 of 804
# 432 of 804
# 433 of 804
# 434 of 804
# 435 of 804
# 436 of 804
# 437 of 804
# Pause to rest. Run time : 78.59 minutes
#
# Scraping page :
# 438 of 804
# 439 of 804
# 440 of 804
# 441 of 804
# 442 of 804
# 443 of 804
# Pause to rest. Run time : 79.56 minutes
#
# Scraping page :
# 444 of 804
# 445 of 804
# 446 of 804
# 447 of 804
# 448 of 804
# 449 of 804
# 450 of 804, Run time : 80.86 minutes
# 451 of 804
# 452 of 804
# 453 of 804
# 454 of 804
# 455 of 804
# 456 of 804
# 457 of 804
# 458 of 804
# 459 of 804
# 460 of 804
# 461 of 804
# 462 of 804
# 463 of 804
# 464 of 804
# 465 of 804
# 466 of 804
# 467 of 804
# 468 of 804
# 469 of 804
# 470 of 804
# 471 of 804
# 472 of 804
# 473 of 804
# 474 of 804
# 475 of 804
# 476 of 804
# 477 of 804
# 478 of 804
# 479 of 804
# 480 of 804
# 481 of 804
# 482 of 804
# 483 of 804
# 484 of 804
# 485 of 804
# 486 of 804
# Refreshing page 487...
# Refreshing page 487...
# 487 of 804
# 488 of 804
# 489 of 804
# 490 of 804
# 491 of 804
# 492 of 804
# 493 of 804
# 494 of 804
# 495 of 804
# 496 of 804
# 497 of 804
# 498 of 804
# 499 of 804
# 500 of 804, Run time : 89.27 minutes
# 501 of 804
# 502 of 804
# 503 of 804
# 504 of 804
# 505 of 804
# 506 of 804
# 507 of 804
# 508 of 804
# 509 of 804
# 510 of 804
# Pause to rest. Run time : 90.71 minutes
#
# Scraping page :
# 511 of 804
# 512 of 804
# 513 of 804
# 514 of 804
# 515 of 804
# 516 of 804
# 517 of 804
# Pause to rest. Run time : 91.75 minutes
#
# Scraping page :
# 518 of 804
# 519 of 804
# 520 of 804
# 521 of 804
# 522 of 804
# 523 of 804
# 524 of 804
# 525 of 804
# 526 of 804
# 527 of 804
# 528 of 804
# 529 of 804
# 530 of 804
# 531 of 804
# 532 of 804
# 533 of 804
# 534 of 804
# 535 of 804
# 536 of 804
# 537 of 804
# 538 of 804
# 539 of 804
# 540 of 804
# 541 of 804
# 542 of 804
# 543 of 804
# 544 of 804
# 545 of 804
# 546 of 804
# 547 of 804
# 548 of 804
# 549 of 804
# 550 of 804, Run time : 95.9 minutes
# 551 of 804
# 552 of 804
# 553 of 804
# 554 of 804
# 555 of 804
# 556 of 804
# 557 of 804
# 558 of 804
# 559 of 804
# 560 of 804
# 561 of 804
# 562 of 804
# 563 of 804
# 564 of 804
# 565 of 804
# 566 of 804
# 567 of 804
# 568 of 804
# 569 of 804
# 570 of 804
# 571 of 804
# 572 of 804
# 573 of 804
# 574 of 804
# 575 of 804
# 576 of 804
# 577 of 804
# 578 of 804
# 579 of 804
# 580 of 804
# 581 of 804
# 582 of 804
# 583 of 804
# Pause to rest. Run time : 100.13 minutes
#
# Scraping page :
# 584 of 804
# 585 of 804
# 586 of 804
# 587 of 804
# 588 of 804
# 589 of 804
# 590 of 804
# 591 of 804
# Pause to rest. Run time : 101.17 minutes
#
# Scraping page :
# 592 of 804
# 593 of 804
# 594 of 804
# Refreshing page 595...
# 595 of 804
# 596 of 804
# 597 of 804
# 598 of 804
# 599 of 804
# 600 of 804, Run time : 102.56 minutes
# 601 of 804
# 602 of 804
# 603 of 804
# 604 of 804
# Refreshing page 605...
# 605 of 804
# 606 of 804
# Refreshing page 607...
# 607 of 804
# 608 of 804
# 609 of 804
# 610 of 804
# 611 of 804
# 612 of 804
# 613 of 804
# 614 of 804
# 615 of 804
# 616 of 804
# 617 of 804
# 618 of 804
# 619 of 804
# 620 of 804
# 621 of 804
# 622 of 804
# 623 of 804
# 624 of 804
# 625 of 804
# 626 of 804
# 627 of 804
# 628 of 804
# 629 of 804
# 630 of 804
# 631 of 804
# 632 of 804
# 633 of 804
# 634 of 804
# 635 of 804
# 636 of 804
# 637 of 804
# 638 of 804
# 639 of 804
# 640 of 804
# 641 of 804
# 642 of 804
# 643 of 804
# 644 of 804
# 645 of 804
# 646 of 804
# 647 of 804
# 648 of 804
# 649 of 804
# 650 of 804, Run time : 109.21 minutes
# 651 of 804
# 652 of 804
# 653 of 804
# 654 of 804
# 655 of 804
# 656 of 804
# Pause to rest. Run time : 109.93 minutes
#
# Scraping page :
# 657 of 804
# 658 of 804
# 659 of 804
# 660 of 804
# 661 of 804
# 662 of 804
# 663 of 804
# 664 of 804
# 665 of 804
# Pause to rest. Run time : 111.18 minutes
#
# Scraping page :
# 666 of 804
# 667 of 804
# 668 of 804
# 669 of 804
# 670 of 804
# 671 of 804
# 672 of 804
# 673 of 804
# 674 of 804
# 675 of 804
# 676 of 804
# 677 of 804
# 678 of 804
# 679 of 804
# 680 of 804
# 681 of 804
# 682 of 804
# 683 of 804
# 684 of 804
# 685 of 804
# 686 of 804
# 687 of 804
# 688 of 804
# 689 of 804
# 690 of 804
# 691 of 804
# 692 of 804
# 693 of 804
# 694 of 804
# 695 of 804
# 696 of 804
# 697 of 804
# 698 of 804
# 699 of 804
# 700 of 804, Run time : 115.98 minutes
# 701 of 804
# 702 of 804
# 703 of 804
# 704 of 804
# 705 of 804
# 706 of 804
# 707 of 804
# 708 of 804
# 709 of 804
# 710 of 804
# 711 of 804
# 712 of 804
# 713 of 804
# 714 of 804
# 715 of 804
# 716 of 804
# 717 of 804
# 718 of 804
# 719 of 804
# 720 of 804
# 721 of 804
# 722 of 804
# 723 of 804
# 724 of 804
# 725 of 804
# 726 of 804
# 727 of 804
# 728 of 804
# 729 of 804
# Pause to rest. Run time : 120.15 minutes
#
# Scraping page :
# 730 of 804
# 731 of 804
# 732 of 804
# 733 of 804
# 734 of 804
# 735 of 804
# 736 of 804
# 737 of 804
# 738 of 804
# 739 of 804
# Pause to rest. Run time : 121.79 minutes
#
# Scraping page :
# 740 of 804
# 741 of 804
# 742 of 804
# 743 of 804
# 744 of 804
# 745 of 804
# 746 of 804
# 747 of 804
# 748 of 804
# 749 of 804
# 750 of 804, Run time : 124.55 minutes
# 751 of 804
# 752 of 804
# 753 of 804
# 754 of 804
# 755 of 804
# 756 of 804
# 757 of 804
# 758 of 804
# 759 of 804
# 760 of 804
# 761 of 804
# 762 of 804
# 763 of 804
# 764 of 804
# 765 of 804
# 766 of 804
# 767 of 804
# 768 of 804
# 769 of 804
# 770 of 804
# 771 of 804
# 772 of 804
# 773 of 804
# 774 of 804
# 775 of 804
# 776 of 804
# 777 of 804
# 778 of 804
# 779 of 804
# 780 of 804
# 781 of 804
# 782 of 804
# 783 of 804
# 784 of 804
# 785 of 804
# 786 of 804
# 787 of 804
# 788 of 804
# 789 of 804
# 790 of 804
# 791 of 804
# 792 of 804
# 793 of 804
# 794 of 804
# 795 of 804
# 796 of 804
# 797 of 804
# 798 of 804
# 799 of 804
# 800 of 804, Run time : 137.32 minutes
# 801 of 804
# 802 of 804
# Pause to rest. Run time : 137.84 minutes
#
# Scraping page :
# 803 of 804
# 804 of 804
#
# Successfully scraped for Apple interviews.
# Total duration : 138.45 minutes

# %%
apple_df['source'] = 'Apple'

# %%
apple_df
# Out:
#                                                question           offer  \
# 0      The most difficult area is they asked me very...  Accepted Offer
# 1      What is your passion in life? Name a time you...  Accepted Offer
# 2                                                   NaN        No Offer
# 3            Describe yourself in several sentences.           No Offer
# 4                 Q: How do you spend your off time?           No Offer
# ...                                                 ...             ...
# 8035                                                NaN  Declined Offer
# 8036   Une situation où vous avez du faire face à un...  Accepted Offer
# 8037                    Was verbinden Sie mit Apple?           No Offer
# 8038                                                NaN  Accepted Offer
# 8039                                                NaN  Declined Offer
#
#                experience           difficulty  \
# 0     Difficult Interview                  NaN
# 1     Positive Experience  Difficult Interview
# 2     Positive Experience  Difficult Interview
# 3      Neutral Experience       Easy Interview
# 4     Positive Experience       Easy Interview
# ...                   ...                  ...
# 8035  Negative Experience       Easy Interview
# 8036  Negative Experience    Average Interview
# 8037   Neutral Experience  Difficult Interview
# 8038   Neutral Experience    Average Interview
# 8039   Neutral Experience    Average Interview
#
#                                               interview source
# 0                                                   NaN  Apple
# 1                                                   NaN  Apple
# 2                                                   NaN  Apple
# 3                                                   NaN  Apple
# 4                                                   NaN  Apple
# ...                                                 ...    ...
# 8035                                                NaN  Apple
# 8036                                                NaN  Apple
# 8037  Das Karriere Portal von Apple ist sehr umfangr...  Apple
# 8038  Een bijeenkomst, een gesprek, dan nog een (kle...  Apple
# 8039  goed georganiseerd. Telefonisch werd alles uit...  Apple
#
# [8040 rows x 6 columns]

# %%
apple_df.to_csv('../datasets/apple.csv', index = False)
