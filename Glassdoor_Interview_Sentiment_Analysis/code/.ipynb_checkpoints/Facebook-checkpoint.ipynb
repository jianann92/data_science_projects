# %%
# Importing libraries

import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from matplotlib.pyplot import get_cmap

import plotly.express as px
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import regex as re
import requests
from lxml import html
import getpass
from googletrans import Translator
import unicodedata
# Out:
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import random

opts = Options()
opts.add_argument('user-agent=polar-bear 3.0')
opts.add_argument("--headless")

# %%
email = getpass.getpass('Email : ')
password = getpass.getpass('Password : ')

try: 
    driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts) 
    driver.get('https://www.glassdoor.sg/index.htm') 
    driver.implicitly_wait(15)
    
    loginpage = driver.find_element_by_xpath('//*[@id="TopNav"]/nav/div/div/div[4]/div[1]/a')
    loginpage.click()

    loginBox = driver.find_element_by_xpath('//*[@id="userEmail"]') 
    loginBox.send_keys(email)
    
    passWordBox = driver.find_element_by_xpath('//*[@id="userPassword"]')
    passWordBox.send_keys(password)
    
    signin = driver.find_element_by_xpath('//*[@id="LoginModal"]/div/div/div[2]/div[2]/div[2]/div/div/div/div[3]/form/div[3]/div[1]/button')
    signin.click()
    
    print('Login Successful!')

except:
    print('Login Failed')
# Out:
# Email : ········
# Password : ········
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [C:\Users\jiana\.wdm\drivers\chromedriver\win32\86.0.4240.22\chromedriver.exe] found in cache
# <ipython-input-3-4fcec7ff2489>:5: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts)
# Login Successful!

# %%
url = 'https://www.glassdoor.sg/Interview/Facebook-Interview-Questions-E40772.htm'
next_url = None
page = 1
num = 0
main_dict = []     # Different parts
prevent = [37,73]
max_page = 642             # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(3,4))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(5,8))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    facebook_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name
    facebook_df.to_csv('../datasets/facebook.csv', index = False)

# 543 of 641
# 544 of 641
# 545 of 641
# 546 of 641
# 547 of 641
# 548 of 641
# 549 of 641
# 550 of 641, Run time : 68.16 minutes
# 551 of 641
# 552 of 641
# 553 of 641
# 554 of 641
# 555 of 641
# 556 of 641
# 557 of 641
# 558 of 641
# 559 of 641
# 560 of 641
# 561 of 641
# 562 of 641
# 563 of 641
# 564 of 641
# 565 of 641
# 566 of 641
# 567 of 641
# 568 of 641
# 569 of 641
# 570 of 641
# 571 of 641
# 572 of 641
# 573 of 641
# 574 of 641
# 575 of 641
# 576 of 641
# 577 of 641
# 578 of 641
# 579 of 641
# 580 of 641
# 581 of 641
# 582 of 641
# 583 of 641
# Pause to rest. Run time : 73.71 minutes
#
# Scraping page :
# 584 of 641
# 585 of 641
# 586 of 641
# 587 of 641
# 588 of 641
# 589 of 641
# 590 of 641
# 591 of 641
# Pause to rest. Run time : 75.17 minutes
#
# Scraping page :
# 592 of 641
# 593 of 641
# 594 of 641
# 595 of 641
# 596 of 641
# 597 of 641
# 598 of 641
# 599 of 641
# 600 of 641, Run time : 76.64 minutes
# 601 of 641
# 602 of 641
# 603 of 641
# 604 of 641
# 605 of 641
# 606 of 641
# 607 of 641
# 608 of 641
# 609 of 641
# 610 of 641
# 611 of 641
# 612 of 641
# 613 of 641
# 614 of 641
# 615 of 641
# 616 of 641
# 617 of 641
# 618 of 641
# 619 of 641
# 620 of 641
# 621 of 641
# 622 of 641
# 623 of 641
# 624 of 641
# 625 of 641
# 626 of 641
# 627 of 641
# 628 of 641
# 629 of 641
# 630 of 641
# 631 of 641
# 632 of 641
# 633 of 641
# 634 of 641
# 635 of 641
# 636 of 641
# 637 of 641
# 638 of 641
# 639 of 641
# 640 of 641
# 641 of 641
#
# Successfully scraped for Facebook interviews.
# Total duration : 83.25 minutes

# %%
facebook_df
# Out:
#                                                question           offer  \
# 0                                               None     Accepted Offer
# 1     PLEASE DON'T TAKE THE PHONE SCREENING LIGHTLY!...        No Offer
# 2                                                   NaN        No Offer
# 3                                                   NaN  Accepted Offer
# 4      I signed an NDA and I also can’t really remem...        No Offer
# ...                                                 ...             ...
# 6405        Destacar um assunto atual você que gosta           No Offer
# 6406   Dada uma árvore binária, determinar o valor d...        No Offer
# 6407   Montrez-moi vos projets ? Comment vous décriv...  Declined Offer
# 6408   Ver si un número era capicua, pero con un poc...        No Offer
# 6409                                                NaN        No Offer
#
#                                               interview           experience  \
# 0                                                   NaN                  NaN
# 1     A recruiter contacted me over email and set up...  Positive Experience
# 2                                                   NaN  Positive Experience
# 3                                                   NaN  Positive Experience
# 4                                                   NaN   Neutral Experience
# ...                                                 ...                  ...
# 6405  O processo seletivo é muito diferente do que a...  Positive Experience
# 6406  A primeira etapa do processo seletivo foi uma ...  Negative Experience
# 6407  Entretiens avec un "Product designer", qui tra...  Positive Experience
# 6408  Me contactaron por LinkedIn. Me dieron una sem...  Positive Experience
# 6409                                                NaN   Neutral Experience
#
#                difficulty
# 0                     NaN
# 1                     NaN
# 2       Average Interview
# 3     Difficult Interview
# 4     Difficult Interview
# ...                   ...
# 6405    Average Interview
# 6406    Average Interview
# 6407    Average Interview
# 6408    Average Interview
# 6409    Average Interview
#
# [6410 rows x 5 columns]

# %%
facebook_df['source'] = 'Facebook'

# %%
facebook_df.to_csv('../datasets/facebook.csv', index = False)
