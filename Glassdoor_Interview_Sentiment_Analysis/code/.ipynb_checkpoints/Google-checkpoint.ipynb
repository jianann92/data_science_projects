# %%
# Importing libraries

import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from matplotlib.pyplot import get_cmap

import plotly.express as px
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import regex as re
import requests
from lxml import html
import getpass
from googletrans import Translator
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jiana\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jiana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import random

opts = Options()
opts.add_argument('user-agent=polar-bear 3.0')
opts.add_argument("--headless")

# %%
# driver = webdriver.Chrome(executable_path = 'C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe', chrome_options = opts)

email = getpass.getpass('Email : ')
password = getpass.getpass('Password : ')

try: 
    driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts) 
    driver.get('https://www.glassdoor.sg/index.htm') 
    driver.implicitly_wait(15)
    
    loginpage = driver.find_element_by_xpath('//*[@id="TopNav"]/nav/div/div/div[4]/div[1]/a')
    loginpage.click()

    loginBox = driver.find_element_by_xpath('//*[@id="userEmail"]') 
    loginBox.send_keys(email)
    
    passWordBox = driver.find_element_by_xpath('//*[@id="userPassword"]')
    passWordBox.send_keys(password)
    
    signin = driver.find_element_by_xpath('//*[@id="LoginModal"]/div/div/div[2]/div[2]/div[2]/div/div/div/div[3]/form/div[3]/div[1]/button')
    signin.click()
    
    print('Login Successful!')

except:
    print('Login Failed')
# Out:
# Email : ········
# Password : ········
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [C:\Users\jiana\.wdm\drivers\chromedriver\win32\86.0.4240.22\chromedriver.exe] found in cache
# <ipython-input-3-42d1c69f0a0f>:7: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts)
# Login Successful!

# %%
url = 'https://www.glassdoor.com/Interview/Google-Interview-Questions-E9079.htm'  # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,73]
max_page = 1168             # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(3,4))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(5,8))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    google_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name
    google_df.to_csv('../datasets/google.csv', index = False)

print(f'\nSuccessfully scraped for Google interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# 1 of 1167
# 2 of 1167
# 3 of 1167
# 4 of 1167
# 5 of 1167
# 6 of 1167
# 7 of 1167
# 8 of 1167
# 9 of 1167
# 10 of 1167
# 11 of 1167
# 12 of 1167
# 13 of 1167
# 14 of 1167
# 15 of 1167
# 16 of 1167
# 17 of 1167
# 18 of 1167
# 19 of 1167
# 20 of 1167
# 21 of 1167
# 22 of 1167
# 23 of 1167
# 24 of 1167
# 25 of 1167
# 26 of 1167
# 27 of 1167
# 28 of 1167
# 29 of 1167
# 30 of 1167
# 31 of 1167
# 32 of 1167
# 33 of 1167
# 34 of 1167
# 35 of 1167
# 36 of 1167
# Pause to rest. Run time : 6.05 minutes
#
# Scraping page :
# 37 of 1167
# 38 of 1167
# Refreshing page 39...
# 39 of 1167
# 40 of 1167
# 41 of 1167
# 42 of 1167
# 43 of 1167
# 44 of 1167
# 45 of 1167
# 46 of 1167
# 47 of 1167
# 48 of 1167
# 49 of 1167
# 50 of 1167, Run time : 8.52 minutes
# 51 of 1167
# 52 of 1167
# 53 of 1167
# 54 of 1167
# 55 of 1167
# 56 of 1167
# 57 of 1167
# 58 of 1167
# 59 of 1167
# 60 of 1167
# 61 of 1167
# 62 of 1167
# 63 of 1167
# 64 of 1167
# 65 of 1167
# 66 of 1167
# 67 of 1167
# Refreshing page 68...
# Refreshing page 68...
# Refreshing page 68...
# 68 of 1167
# 69 of 1167
# 70 of 1167
# 71 of 1167
# 72 of 1167
# Pause to rest. Run time : 13.38 minutes
#
# Scraping page :
# 73 of 1167
# Pause to rest. Run time : 13.58 minutes
#
# Scraping page :
# 74 of 1167
# 75 of 1167
# 76 of 1167
# 77 of 1167
# 78 of 1167
# 79 of 1167
# 80 of 1167
# 81 of 1167
# 82 of 1167
# 83 of 1167
# 84 of 1167
# 85 of 1167
# 86 of 1167
# 87 of 1167
# 88 of 1167
# 89 of 1167
# 90 of 1167
# 91 of 1167
# 92 of 1167
# 93 of 1167
# 94 of 1167
# 95 of 1167
# 96 of 1167
# 97 of 1167
# 98 of 1167
# 99 of 1167
# 100 of 1167, Run time : 18.26 minutes
# 101 of 1167
# 102 of 1167
# 103 of 1167
# 104 of 1167
# 105 of 1167
# 106 of 1167
# 107 of 1167
# 108 of 1167
# 109 of 1167
# 110 of 1167
# 111 of 1167
# 112 of 1167
# 113 of 1167
# 114 of 1167
# 115 of 1167
# 116 of 1167
# 117 of 1167
# 118 of 1167
# 119 of 1167
# 120 of 1167
# 121 of 1167
# 1153 of 1167
# 1154 of 1167
# 1155 of 1167
# 1156 of 1167
# 1157 of 1167
# 1158 of 1167
# 1159 of 1167
# 1160 of 1167
# 1161 of 1167
# 1162 of 1167
# 1163 of 1167
# 1164 of 1167
# 1165 of 1167
# 1166 of 1167
# 1167 of 1167
#
# Successfully scraped for Google interviews.
# Total duration : 191.69 minutes

# %%
google_df['source'] = 'Google'

# %%
google_df
# Out:
#                                                interview           offer  \
# 0                                               None.     Accepted Offer
# 1                                         As above...           No Offer
# 2       Tell me about yourself, why do you want work ...        No Offer
# 3                                                    NaN        No Offer
# 4                      Asked to invert a binary tree.           No Offer
# ...                                                  ...             ...
# 11665                                                NaN  Declined Offer
# 11666                                                NaN        No Offer
# 11667                                                NaN        No Offer
# 11668                                                NaN        No Offer
# 11669                                                NaN        No Offer
#
#                 experience           difficulty  source
# 0      Positive Experience  Difficult Interview  Google
# 1      Positive Experience       Easy Interview  Google
# 2       Neutral Experience    Average Interview  Google
# 3      Negative Experience                  NaN  Google
# 4      Positive Experience  Difficult Interview  Google
# ...                    ...                  ...     ...
# 11665  Positive Experience    Average Interview  Google
# 11666  Negative Experience    Average Interview  Google
# 11667   Neutral Experience    Average Interview  Google
# 11668  Positive Experience    Average Interview  Google
# 11669  Negative Experience    Average Interview  Google
#
# [11670 rows x 5 columns]

# %%
google_df.isna().sum()
# Out:
# interview     2524
# offer            0
# experience     415
# difficulty    1017
# source           0
# dtype: int64

# %%
google_df.dropna(inplace = True)

# %%
google_df.isna().sum()
# Out:
# interview     0
# offer         0
# experience    0
# difficulty    0
# source        0
# dtype: int64

# %%
import unicodedata

# %%
google_df['interview'] = google_df['interview'].apply(lambda i : unicodedata.normalize("NFKD", i))
# remove '\xa0' from all texts

# %%
translator = Translator()

# %%
google_df['interview'] = google_df['interview'].apply(lambda i : translator.translate(i, dest = 'en').text)

# %%
google_df
# Out:
#                                                interview           offer  \
# 0                                                  None.  Accepted Offer
# 1                                            As above...        No Offer
# 2      Tell me about yourself, why do you want work h...        No Offer
# 4                         Asked to invert a binary tree.        No Offer
# 5            Matrix and algorithms manipulation question        No Offer
# ...                                                  ...             ...
# 11621  Typical problem solution à la "Cracking the C...  Declined Offer
# 11626                            What's your background?  Accepted Offer
# 11632  Each interviewer asked different questions; Th...  Accepted Offer
# 11653  I don't remember a very difficult question (bu...        No Offer
# 11655  How many ping pong balls can you fit into a sc...  Accepted Offer
#
#                 experience           difficulty  source
# 0      Positive Experience  Difficult Interview  Google
# 1      Positive Experience       Easy Interview  Google
# 2       Neutral Experience    Average Interview  Google
# 4      Positive Experience  Difficult Interview  Google
# 5      Positive Experience    Average Interview  Google
# ...                    ...                  ...     ...
# 11621  Positive Experience  Difficult Interview  Google
# 11626  Positive Experience  Difficult Interview  Google
# 11632  Positive Experience  Difficult Interview  Google
# 11653  Positive Experience    Average Interview  Google
# 11655  Positive Experience  Difficult Interview  Google
#
# [8301 rows x 5 columns]

# %%
google_df.to_csv('../datasets/google.csv', index = False)
