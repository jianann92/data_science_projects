# %%
# Importing libraries

import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from matplotlib.pyplot import get_cmap

import plotly.express as px
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import regex as re
import requests
from lxml import html
import getpass
from googletrans import Translator
import unicodedata
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jiana\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jiana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import random

opts = Options()
opts.add_argument('user-agent=polar-bear 3.0')
opts.add_argument("--headless")

# %%
# driver = webdriver.Chrome(executable_path = 'C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe', chrome_options = opts)

email = getpass.getpass('Email : ')
password = getpass.getpass('Password : ')

try: 
    driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts) 
    driver.get('https://www.glassdoor.sg/index.htm') 
    driver.implicitly_wait(15)
    
    loginpage = driver.find_element_by_xpath('//*[@id="TopNav"]/nav/div/div/div[4]/div[1]/a')
    loginpage.click()

    loginBox = driver.find_element_by_xpath('//*[@id="userEmail"]') 
    loginBox.send_keys(email)
    
    passWordBox = driver.find_element_by_xpath('//*[@id="userPassword"]')
    passWordBox.send_keys(password)
    
    signin = driver.find_element_by_xpath('//*[@id="LoginModal"]/div/div/div[2]/div[2]/div[2]/div/div/div/div[3]/form/div[3]/div[1]/button')
    signin.click()
    
    print('Login Successful!')

except:
    print('Login Failed')
# Out:
# Email : ········
# Password : ········
# [WDM] - Current google-chrome version is 86.0.4240
# [WDM] - Get LATEST driver version for 86.0.4240
# [WDM] - Driver [C:\Users\jiana\.wdm\drivers\chromedriver\win32\86.0.4240.22\chromedriver.exe] found in cache
# <ipython-input-3-42d1c69f0a0f>:7: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options = opts)
# Login Successful!

# %%
url = 'https://www.glassdoor.sg/Interview/Microsoft-Interview-Questions-E1651.htm' # Change URL to company you want
next_url = None
page = 1
num = 0
main_dict = []
prevent = [37,73]
max_page = 976             # Change the page number to the number of pages you want to web scrape
start_time = time.time()

print('Scraping page :')

while page < max_page:
    if next_url == None:
        next_url = url    
    
    else:
        next_url = 'https://www.glassdoor.com'+after
    
    if page % prevent[num] == 0:
        print(f'Pause to rest. Run time : {round((time.time() - start_time)/60,2)} minutes\n')
        time.sleep(random.randint(3,5))
        print('Scraping page :')
        num = 1 - num
    
    driver.get(next_url)
    time.sleep(random.randint(1,3))
    
    post = html.fromstring(driver.page_source)
    get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]
 
    while len(get_id) < 10:
        print(f'Refreshing page {page}...')
        driver.get(next_url)
        time.sleep(random.randint(2,4))
        post = html.fromstring(driver.page_source)
        get_id = post.xpath('//*[contains(@id,"InterviewReview")]')[1:]

    for i in range(len(get_id)):
        
        id_pos = get_id[i].attrib['id']
        interview_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[1]/p[4]/text()')
        question_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[2]/div/div[2]/ul/li/span/text()')
        offer_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[1]/div/div[2]/span/text()')
        experience_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[2]/div/div[2]/span/text()')
        difficulty_ = post.xpath(f'//*[@id="{id_pos}"]/div[3]/div/div[2]/div[1]/div/div[3]/div/div[2]/span/text()')
        
        page_frame = {}
        
        if len(interview_) == 1:
            page_frame['interview'] = interview_[0]
            
        if len(question_) == 1:
            page_frame['question'] = question_[0]
        
        if len(offer_) == 1:
            page_frame['offer'] = offer_[0]

        if len(experience_) == 1:
            page_frame['experience'] = experience_[0]

        if len(difficulty_) == 1:
            page_frame['difficulty'] = difficulty_[0]
        
        main_dict.append(page_frame)

    if page % 50 == 0:
        print(f'{page} of {max_page-1}, Run time : {round((time.time() - start_time)/60,2)} minutes')
        
    else:
        print(f'{page} of {max_page-1}')
    
    page+=1
    after = post.xpath('//*[@id="FooterPageNav"]/div[2]/ul/li[7]/a/@href')[0]
    microsoft_df = pd.DataFrame(main_dict)                                        # Change the data frame and csv name
    microsoft_df.to_csv('../datasets/microsoft.csv', index = False)

print(f'\nSuccessfully scraped for Microsoft interviews.\nTotal duration : {round((time.time() - start_time)/60,2)} minutes')
# Change the name of company you are scraping
# Out:
# Scraping page :
# Refreshing page 1...
# 1 of 975
# 2 of 975
# 3 of 975
# 4 of 975
# 5 of 975
# 6 of 975
# 7 of 975
# 8 of 975
# 9 of 975
# 10 of 975
# 11 of 975
# 12 of 975
# 13 of 975
# 14 of 975
# 15 of 975
# 16 of 975
# 17 of 975
# 18 of 975
# 19 of 975
# 20 of 975
# 21 of 975
# 22 of 975
# 23 of 975
# 24 of 975
# 25 of 975
# 26 of 975
# 27 of 975
# 28 of 975
# 29 of 975
# 30 of 975
# 31 of 975
# 32 of 975
# 33 of 975
# 34 of 975
# 35 of 975
# 36 of 975
# Pause to rest. Run time : 8.58 minutes
#
# Scraping page :
# 37 of 975
# 38 of 975
# 39 of 975
# 40 of 975
# 41 of 975
# 42 of 975
# 43 of 975
# 44 of 975
# 45 of 975
# 46 of 975
# 47 of 975
# 48 of 975
# 49 of 975
# 50 of 975, Run time : 12.01 minutes
# 51 of 975
# 52 of 975
# 53 of 975
# 54 of 975
# 55 of 975
# 56 of 975
# 57 of 975
# 58 of 975
# 59 of 975
# 60 of 975
# 61 of 975
# 62 of 975
# 63 of 975
# 64 of 975
# 65 of 975
# 66 of 975
# 67 of 975
# 68 of 975
# 69 of 975
# 70 of 975
# 71 of 975
# 72 of 975
# Pause to rest. Run time : 16.97 minutes
#
# Scraping page :
# 73 of 975
# Pause to rest. Run time : 17.27 minutes
#
# Scraping page :
# 74 of 975
# 75 of 975
# 76 of 975
# 77 of 975
# 78 of 975
# 79 of 975
# 80 of 975
# 81 of 975
# 82 of 975
# 83 of 975
# 84 of 975
# 85 of 975
# 86 of 975
# 87 of 975
# 88 of 975
# 89 of 975
# 90 of 975
# 91 of 975
# 92 of 975
# 93 of 975
# 94 of 975
# 95 of 975
# 96 of 975
# 97 of 975
# 98 of 975
# 99 of 975
# 100 of 975, Run time : 23.79 minutes
# 101 of 975
# 102 of 975
# 103 of 975
# 104 of 975
# 105 of 975
# 106 of 975
# 107 of 975
# 108 of 975
# 109 of 975
# 110 of 975
# 111 of 975
# 112 of 975
# 113 of 975
# 114 of 975
# 115 of 975
# 116 of 975
# 117 of 975
# 118 of 975
# 119 of 975
# 753 of 975
# 754 of 975
# 755 of 975
# 756 of 975
# 757 of 975
# 758 of 975
# 759 of 975
# 760 of 975
# 761 of 975
# 762 of 975
# 763 of 975
# 764 of 975
# 765 of 975
# 766 of 975
# 767 of 975
# 768 of 975
# 769 of 975
# 770 of 975
# 771 of 975
# 772 of 975
# 773 of 975
# 774 of 975
# 775 of 975
# 776 of 975
# 777 of 975
# 778 of 975
# 779 of 975
# 780 of 975
# 781 of 975
# 782 of 975
# 783 of 975
# 784 of 975
# 785 of 975
# 786 of 975
# 787 of 975
# 788 of 975
# 789 of 975
# 790 of 975
# 791 of 975
# 792 of 975
# 793 of 975
# 794 of 975
# 795 of 975
# 796 of 975
# 797 of 975
# 798 of 975
# 799 of 975
# 800 of 975, Run time : 161.85 minutes
# 801 of 975
# 802 of 975
# Pause to rest. Run time : 162.09 minutes
#
# Scraping page :
# 803 of 975
# 804 of 975
# 805 of 975
# 806 of 975
# 807 of 975
# 808 of 975
# 809 of 975
# Refreshing page 810...
# 810 of 975
# 811 of 975
# 812 of 975
# 813 of 975
# Pause to rest. Run time : 163.62 minutes
#
# Scraping page :
# 814 of 975
# 815 of 975
# 816 of 975
# 817 of 975
# 818 of 975
# 819 of 975
# 820 of 975
# 821 of 975
# 822 of 975
# 823 of 975
# 824 of 975
# 825 of 975
# 826 of 975
# 827 of 975
# 828 of 975
# 829 of 975
# 830 of 975
# 831 of 975
# 832 of 975
# 833 of 975
# 834 of 975
# 835 of 975
# 836 of 975
# 837 of 975
# 838 of 975
# 839 of 975
# 840 of 975
# 841 of 975
# 842 of 975
# 843 of 975
# 844 of 975
# 845 of 975
# 846 of 975
# 847 of 975
# 848 of 975
# 849 of 975
# 850 of 975, Run time : 168.65 minutes
# 851 of 975
# 852 of 975
# 853 of 975
# 854 of 975
# 855 of 975
# 856 of 975
# 857 of 975
# 858 of 975
# 859 of 975
# 860 of 975
# 861 of 975
# 862 of 975
# 863 of 975
# 864 of 975
# 865 of 975
# 866 of 975
# 867 of 975
# 868 of 975
# 869 of 975
# 870 of 975
# 871 of 975
# 872 of 975
# 873 of 975
# 874 of 975
# 875 of 975
# Pause to rest. Run time : 171.65 minutes
#
# Scraping page :
# 876 of 975
# 877 of 975
# 878 of 975
# 879 of 975
# 880 of 975
# 881 of 975
# 882 of 975
# 883 of 975
# 884 of 975
# 885 of 975
# 886 of 975
# 887 of 975
# Pause to rest. Run time : 173.03 minutes
#
# Scraping page :
# 888 of 975
# 889 of 975
# 890 of 975
# 891 of 975
# 892 of 975
# 893 of 975
# 894 of 975
# 895 of 975
# 896 of 975
# 897 of 975
# 898 of 975
# 899 of 975
# 900 of 975, Run time : 174.51 minutes
# 901 of 975
# 902 of 975
# 903 of 975
# 904 of 975
# 905 of 975
# 906 of 975
# 907 of 975
# 908 of 975
# 909 of 975
# 910 of 975
# 911 of 975
# 912 of 975
# 913 of 975
# 914 of 975
# 915 of 975
# 916 of 975
# 917 of 975
# 918 of 975
# 919 of 975
# 920 of 975
# 921 of 975
# 922 of 975
# 923 of 975
# 924 of 975
# 925 of 975
# 926 of 975
# 927 of 975
# 928 of 975
# 929 of 975
# 930 of 975
# 931 of 975
# 932 of 975
# 933 of 975
# 934 of 975
# 935 of 975
# 936 of 975
# 937 of 975
# 938 of 975
# 939 of 975
# 940 of 975
# 941 of 975
# 942 of 975
# 943 of 975
# 944 of 975
# 945 of 975
# 946 of 975
# 947 of 975
# 948 of 975
# Pause to rest. Run time : 180.94 minutes
#
# Scraping page :
# 949 of 975
# 950 of 975, Run time : 181.24 minutes
# 951 of 975
# 952 of 975
# 953 of 975
# 954 of 975
# 955 of 975
# 956 of 975
# 957 of 975
# 958 of 975
# 959 of 975
# 960 of 975
# 961 of 975
# Pause to rest. Run time : 182.45 minutes
#
# Scraping page :
# 962 of 975
# 963 of 975
# 964 of 975
# 965 of 975
# 966 of 975
# 967 of 975
# 968 of 975
# 969 of 975
# 970 of 975
# 971 of 975
# 972 of 975
# 973 of 975
# 974 of 975
# 975 of 975
#
# Successfully scraped for Microsoft interviews.
# Total duration : 184.57 minutes

# %%
microsoft_df['source'] = 'Microsoft'

# %%
microsoft_df
# Out:
#                                                question           offer  \
# 0         What is your favorite piece of technology?           No Offer
# 1            Describe you experience with x, y, z...           No Offer
# 2                                                   NaN        No Offer
# 3                    What is your greatest strength?     Declined Offer
# 4      Signed NDA. Prepare as you'd normally would f...        No Offer
# ...                                                 ...             ...
# 9745            Quelle est la stratégie de Microsoft     Accepted Offer
# 9746             Warum haben Sie sich hier beworben?     Accepted Offer
# 9747                                                NaN        No Offer
# 9748   Penses tu que tu es trop qualifié pour le pos...  Accepted Offer
# 9749                   Qu'attendez vous de Microsoft     Accepted Offer
#
#                experience           difficulty  \
# 0     Negative Experience    Average Interview
# 1      Neutral Experience    Average Interview
# 2     Negative Experience    Average Interview
# 3     Positive Experience    Average Interview
# 4     Negative Experience       Easy Interview
# ...                   ...                  ...
# 9745  Positive Experience    Average Interview
# 9746   Neutral Experience    Average Interview
# 9747    Average Interview                  NaN
# 9748  Positive Experience    Average Interview
# 9749  Positive Experience  Difficult Interview
#
#                                               interview     source
# 0                                                   NaN  Microsoft
# 1     Applied to the role and was asked to fill out ...  Microsoft
# 2                                                   NaN  Microsoft
# 3                                                   NaN  Microsoft
# 4                                                   NaN  Microsoft
# ...                                                 ...        ...
# 9745                                                NaN  Microsoft
# 9746                                                NaN  Microsoft
# 9747  Sehr offene und hilfsbereite Arbeitskultur. Mo...  Microsoft
# 9748  Seulement un tour avec les supérieurs directs....  Microsoft
# 9749  1 entretien téléphonique, 2 entretiens manager...  Microsoft
#
# [9750 rows x 6 columns]

# %%
microsoft_df.to_csv('../datasets/microsoft.csv', index = False)
